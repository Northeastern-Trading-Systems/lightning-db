# %% [markdown]
# # Connecting to DB in RDS Guide
# ### Miles Child - November 2022
# #### Northeastern Trading Systems

# %% [markdown]
# #### Starting DB and importing necessary packages
#
# Once you have created your database in RDS, make sure that it is configured to be publicly accessible and that you've attached a security group that allows inbound/outbound access from 'All Traffic' on both IPv4 and IPv6. Save the login credentials of the DB as soon as you launch the instance.
#
# Next, navigate to your local python environment and install the pymysql package. This process can be very messy if done incorrectly the first time, so make sure you do the following:
#
# For Python 2.x:
# - sudo pip install pymysql.
#
# For Python 3.x:
# - sudo pip3 install pymysql.
#
# For either running on Anaconda:
# - sudo conda install pymysql.
#
# If that didn't work try APT:
# - sudo apt-get install pymysql.
#
# credit: https://stackoverflow.com/a/49354387/20355075
#
# Finally, 'import pymysql' in your project before continuing.

# %%
# imports
import pymysql
from model.config import *  # credentials stored here

# %% [markdown]
# Now, establish a connection to the db by using pymysql.connect(host=<'someurl.rds.amazonaws.com'>, user=<'username'>, password=<'password'>).
#
# Create a cursor, which can essentially be regarded as an object that executes your queries (written locally) on the DB, stores the result in-memory, and returns it back to this project. Check that the connection and cursor have been made properly by checking the version of the db.

# %%
connection = pymysql.connect(host=RDS_HOSTNAME, user=RDS_USER, password=RDS_PASSWORD,
 database='nts_lightning_db_v2', # <-- Optional: The name of the database to connect to. Can be left blank and changed later.
  autocommit=True # <-- Optional: If set to True, the connection will autocommit after every query. This is useful for queries that don't modify the database.
  )
cursor = connection.cursor()
cursor.execute('select version()')
# Out:
# 1

# %%
cursor.execute('select * from strategy')
# Out:
# 10

# %% [markdown]
# After successfully establishing a connection to the RDS instance, create a DB and add the neccessary tables/entities/attributes.

# %%
# Create a new database
cursor.execute("CREATE DATABASE nts_lightning_db;")
cursor.execute(f"CREATE USER 'webapp'@'%' IDENTIFIED BY {DOCKER_DB_PASSWORD};")
cursor.execute("GRANT ALL PRIVILEGES ON nts_lightning_db.* TO 'webapp'@'%';")
cursor.execute("FLUSH PRIVILEGES;")
cursor.execute("USE nts_lightning_db;")

# %%
# Create the tables
cursor.execute("""CREATE TABLE strategy (
    strategy_name varchar(50),
    strategy_id integer AUTO_INCREMENT NOT NULL,
    documentation_link varchar(50),
    launch_date datetime,
    termination_date datetime,
    PRIMARY KEY (strategy_id)
);""")

# %%
cursor.execute("""CREATE TABLE trade (
    trade_id integer UNIQUE NOT NULL,
    strategy_id integer,
    open_time datetime,
    close_time datetime,
    PRIMARY KEY (trade_id),
    CONSTRAINT fk_1 
        FOREIGN KEY (strategy_id) REFERENCES strategy(strategy_id)
        ON UPDATE cascade ON DELETE restrict
);""")

# %%
cursor.execute("""CREATE TABLE trade_leg (
    leg_no integer NOT NULL,
    trade_id integer NOT NULL,
    contract varchar(50),
    open_time datetime,
    close_time datetime,
    PRIMARY KEY(leg_no, trade_id),
    CONSTRAINT fk_2
        FOREIGN KEY (trade_id) REFERENCES trade (trade_id)
        ON UPDATE restrict ON DELETE restrict
);""")

# %%
cursor.execute("""CREATE TABLE fill (
    fill_id integer NOT NULL,
    leg_no integer NOT NULL,
    trade_id integer NOT NULL,
    contract varchar(50),
    qty integer,
    avg float(32),
    placement_time datetime,
    filled_time datetime,
    PRIMARY KEY (fill_id),
    CONSTRAINT fk_3
        FOREIGN KEY (leg_no, trade_id) REFERENCES trade_leg (leg_no, trade_id)
        ON UPDATE cascade ON DELETE restrict
);""")

# %% [markdown]
# After creating the database architecture, insert testing (or historical) data into the tables.
#
# note: mockaroo is good for generating dummy data https://www.mockaroo.com/

# %%
# Manual Entry: Dummy data
cursor.execute("""INSERT INTO strategy (strategy_name,strategy_id,documentation_link,launch_date,termination_date) 
values 
('MeanReversionLunchBreak', '1', 'https://github.com/QuantConnect/Lean/blob/master/Algorithm.Python/Alphas/MeanReversionLunchBreakAlpha.py',
 '2022-11-20 00:00:00', NULL);""")

# %% [markdown]
# Below is an example of how to insert data programmatically given a list of preexisting SQL insert statements. Websites like https://www.convertcsv.com/csv-to-sql.htm allow you to take a csv and generate SQL insert statements for every entry, which can then be pasted below.
#
# note: it is also possible to use the build in file reading query in MySQL.

# %%
# Fast Entry: Dummy data
# Copy and paste SQL insert statements into the below variable:
txt = """SELECT * FROM strategy""" # <-- Replace with your SQL insert statements
txt = txt.split(';') # <-- Split by the end of each insert statement
for insertion in txt:
    cursor.execute(insertion)

# %%
# Testing that all dummy data was inserted properly and exists in the db.

cursor.execute('SELECT * from fill;')
col_headers = [x[0] for x in cursor.description]
json_data = []
the_data = cursor.fetchall()
for row in the_data:
    json_data.append(dict(zip(col_headers, row)))
json_data
# Out:
# [{'fill_id': 715132,
#   'leg_no': 1,
#   'trade_id': 51254898,
#   'contract': 'TAX',
#   'qty': -328,
#   'avg': 521.6912281962,
#   'placement_time': datetime.datetime(2022, 3, 10, 16, 29, 10),
#   'filled_time': datetime.datetime(2022, 3, 10, 16, 29, 17)},
#  {'fill_id': 954417,
#   'leg_no': 1,
#   'trade_id': 452572457,
#   'contract': 'CVO',
#   'qty': 490,
#   'avg': 325.09,
#   'placement_time': datetime.datetime(2022, 2, 28, 7, 49, 31),
#   'filled_time': datetime.datetime(2022, 2, 28, 7, 49, 41)},
#  {'fill_id': 12218623,
#   'leg_no': 1,
#   'trade_id': 376975473,
#   'contract': 'CLLS',
#   'qty': -235,
#   'avg': 161.3184553646,
#   'placement_time': datetime.datetime(2022, 3, 15, 6, 6, 53),
#   'filled_time': datetime.datetime(2022, 3, 15, 6, 6, 58)},
#  {'fill_id': 14754413,
#   'leg_no': 1,
#   'trade_id': 44409115,
#   'contract': 'WAGE',
#   'qty': -407,
#   'avg': 447.5675880229,
#   'placement_time': datetime.datetime(2022, 10, 1, 5, 5),
#   'filled_time': datetime.datetime(2022, 10, 1, 5, 5, 9)},
#  {'fill_id': 16642096,
#   'leg_no': 1,
#   'trade_id': 918081156,
#   'contract': 'L',
#   'qty': 291,
#   'avg': 311.5,
#   'placement_time': datetime.datetime(2022, 3, 7, 4, 56, 39),
#   'filled_time': datetime.datetime(2022, 3, 7, 4, 56, 40)},
#  {'fill_id': 20572043,
#   'leg_no': 1,
#   'trade_id': 603296925,
#   'contract': 'UNM',
#   'qty': 401,
#   'avg': 134.26,
#   'placement_time': datetime.datetime(2022, 2, 2, 23, 43, 14),
#   'filled_time': datetime.datetime(2022, 2, 2, 23, 43, 21)},
#  {'fill_id': 20765247,
#   'leg_no': 1,
#   'trade_id': 324101738,
#   'contract': 'QQQX',
#   'qty': 423,
#   'avg': 99.74,
#   'placement_time': datetime.datetime(2022, 10, 14, 18, 52, 55),
#   'filled_time': datetime.datetime(2022, 10, 14, 18, 52, 57)},
#  {'fill_id': 21277373,
#   'leg_no': 1,
#   'trade_id': 872630201,
#   'contract': 'RDC',
#   'qty': -217,
#   'avg': 359.0828183404,
#   'placement_time': datetime.datetime(2022, 4, 11, 8, 0, 46),
#   'filled_time': datetime.datetime(2022, 4, 11, 8, 0, 48)},
#  {'fill_id': 22062250,
#   'leg_no': 1,
#   'trade_id': 496707528,
#   'contract': 'ENDP',
#   'qty': 204,
#   'avg': 481.69,
#   'placement_time': datetime.datetime(2022, 6, 18, 22, 19, 11),
#   'filled_time': datetime.datetime(2022, 6, 18, 22, 19, 15)},
#  {'fill_id': 27887192,
#   'leg_no': 1,
#   'trade_id': 95862058,
#   'contract': 'WASH',
#   'qty': -129,
#   'avg': 417.9484032288,
#   'placement_time': datetime.datetime(2022, 1, 5, 23, 7, 40),
#   'filled_time': datetime.datetime(2022, 1, 5, 23, 7, 45)},
#  {'fill_id': 30275677,
#   'leg_no': 1,
#   'trade_id': 397180433,
#   'contract': 'ALX',
#   'qty': 346,
#   'avg': 398.16,
#   'placement_time': datetime.datetime(2021, 12, 19, 16, 12, 7),
#   'filled_time': datetime.datetime(2021, 12, 19, 16, 12, 11)},
#  {'fill_id': 37797072,
#   'leg_no': 1,
#   'trade_id': 667385692,
#   'contract': 'MTGEP',
#   'qty': 480,
#   'avg': 226.39,
#   'placement_time': datetime.datetime(2022, 3, 1, 6, 20, 40),
#   'filled_time': datetime.datetime(2022, 3, 1, 6, 20, 47)},
#  {'fill_id': 38066907,
#   'leg_no': 1,
#   'trade_id': 366846045,
#   'contract': 'EFAS',
#   'qty': -342,
#   'avg': 240.5856947756,
#   'placement_time': datetime.datetime(2022, 11, 5, 8, 8, 54),
#   'filled_time': datetime.datetime(2022, 11, 5, 8, 8, 57)},
#  {'fill_id': 47590116,
#   'leg_no': 1,
#   'trade_id': 88451452,
#   'contract': 'DRWI',
#   'qty': 142,
#   'avg': 42.48,
#   'placement_time': datetime.datetime(2022, 4, 16, 9, 59, 24),
#   'filled_time': datetime.datetime(2022, 4, 16, 9, 59, 24)},
#  {'fill_id': 50777197,
#   'leg_no': 1,
#   'trade_id': 868094915,
#   'contract': 'AKBA',
#   'qty': 251,
#   'avg': 360.75,
#   'placement_time': datetime.datetime(2022, 1, 25, 16, 7, 20),
#   'filled_time': datetime.datetime(2022, 1, 25, 16, 7, 29)},
#  {'fill_id': 52740558,
#   'leg_no': 1,
#   'trade_id': 491606976,
#   'contract': 'TSRI',
#   'qty': 444,
#   'avg': 180.27,
#   'placement_time': datetime.datetime(2022, 8, 19, 20, 0, 32),
#   'filled_time': datetime.datetime(2022, 8, 19, 20, 0, 34)},
#  {'fill_id': 52905032,
#   'leg_no': 1,
#   'trade_id': 4965884,
#   'contract': 'LORL',
#   'qty': -203,
#   'avg': 63.6409253308,
#   'placement_time': datetime.datetime(2022, 11, 29, 14, 0, 55),
#   'filled_time': datetime.datetime(2022, 11, 29, 14, 0, 56)},
#  {'fill_id': 53435003,
#   'leg_no': 1,
#   'trade_id': 550650228,
#   'contract': 'ONSIW',
#   'qty': -308,
#   'avg': 365.3433568869,
#   'placement_time': datetime.datetime(2022, 4, 3, 5, 19, 28),
#   'filled_time': datetime.datetime(2022, 4, 3, 5, 19, 34)},
#  {'fill_id': 53446702,
#   'leg_no': 1,
#   'trade_id': 363242941,
#   'contract': 'GOGL',
#   'qty': 224,
#   'avg': 261.43,
#   'placement_time': datetime.datetime(2022, 7, 21, 2, 30, 47),
#   'filled_time': datetime.datetime(2022, 7, 21, 2, 30, 55)},
#  {'fill_id': 53892004,
#   'leg_no': 1,
#   'trade_id': 4965884,
#   'contract': 'LORL',
#   'qty': 203,
#   'avg': 84.99,
#   'placement_time': datetime.datetime(2022, 6, 18, 6, 27, 55),
#   'filled_time': datetime.datetime(2022, 6, 18, 6, 28, 5)},
#  {'fill_id': 55779593,
#   'leg_no': 1,
#   'trade_id': 429373670,
#   'contract': 'ISBC',
#   'qty': 163,
#   'avg': 307.8,
#   'placement_time': datetime.datetime(2022, 1, 30, 11, 32, 37),
#   'filled_time': datetime.datetime(2022, 1, 30, 11, 32, 44)},
#  {'fill_id': 58856095,
#   'leg_no': 1,
#   'trade_id': 78371468,
#   'contract': 'DVD',
#   'qty': 488,
#   'avg': 281.87,
#   'placement_time': datetime.datetime(2022, 11, 17, 14, 50, 10),
#   'filled_time': datetime.datetime(2022, 11, 17, 14, 50, 16)},
#  {'fill_id': 63011320,
#   'leg_no': 1,
#   'trade_id': 156658556,
#   'contract': 'PDLI',
#   'qty': 334,
#   'avg': 340.06,
#   'placement_time': datetime.datetime(2022, 7, 22, 22, 8, 30),
#   'filled_time': datetime.datetime(2022, 7, 22, 22, 8, 31)},
#  {'fill_id': 66241638,
#   'leg_no': 1,
#   'trade_id': 122164559,
#   'contract': 'NWL',
#   'qty': -478,
#   'avg': 180.1737130617,
#   'placement_time': datetime.datetime(2022, 9, 25, 3, 51, 25),
#   'filled_time': datetime.datetime(2022, 9, 25, 3, 51, 26)},
#  {'fill_id': 70264479,
#   'leg_no': 1,
#   'trade_id': 771132787,
#   'contract': 'SFUN',
#   'qty': -183,
#   'avg': 418.7484831715,
#   'placement_time': datetime.datetime(2022, 10, 8, 4, 40, 59),
#   'filled_time': datetime.datetime(2022, 10, 8, 4, 41, 5)},
#  {'fill_id': 70269322,
#   'leg_no': 1,
#   'trade_id': 550413487,
#   'contract': 'WAFDW',
#   'qty': 424,
#   'avg': 128.72,
#   'placement_time': datetime.datetime(2021, 12, 8, 1, 27, 48),
#   'filled_time': datetime.datetime(2021, 12, 8, 1, 27, 48)},
#  {'fill_id': 72102377,
#   'leg_no': 1,
#   'trade_id': 580798972,
#   'contract': 'LBIO',
#   'qty': -328,
#   'avg': 354.0874537313,
#   'placement_time': datetime.datetime(2022, 6, 29, 18, 25, 47),
#   'filled_time': datetime.datetime(2022, 6, 29, 18, 25, 56)},
#  {'fill_id': 73902352,
#   'leg_no': 1,
#   'trade_id': 998104368,
#   'contract': 'XRX',
#   'qty': 235,
#   'avg': 33.27,
#   'placement_time': datetime.datetime(2022, 5, 25, 23, 59, 27),
#   'filled_time': datetime.datetime(2022, 5, 25, 23, 59, 32)},
#  {'fill_id': 74897657,
#   'leg_no': 1,
#   'trade_id': 231075256,
#   'contract': 'KWR',
#   'qty': -426,
#   'avg': 259.2188000976,
#   'placement_time': datetime.datetime(2022, 10, 1, 12, 36, 21),
#   'filled_time': datetime.datetime(2022, 10, 1, 12, 36, 26)},
#  {'fill_id': 77706377,
#   'leg_no': 1,
#   'trade_id': 4555319,
#   'contract': 'EMCF',
#   'qty': 425,
#   'avg': 387.68,
#   'placement_time': datetime.datetime(2022, 6, 1, 0, 12, 28),
#   'filled_time': datetime.datetime(2022, 6, 1, 0, 12, 31)},
#  {'fill_id': 78954099,
#   'leg_no': 1,
#   'trade_id': 550650228,
#   'contract': 'ONSIW',
#   'qty': 308,
#   'avg': 372.99,
#   'placement_time': datetime.datetime(2022, 1, 31, 4, 33, 10),
#   'filled_time': datetime.datetime(2022, 1, 31, 4, 33, 11)},
#  {'fill_id': 79016036,
#   'leg_no': 1,
#   'trade_id': 254513008,
#   'contract': 'FNCX',
#   'qty': 121,
#   'avg': 417.31,
#   'placement_time': datetime.datetime(2022, 6, 9, 20, 24, 16),
#   'filled_time': datetime.datetime(2022, 6, 9, 20, 24, 16)},
#  {'fill_id': 79834377,
#   'leg_no': 1,
#   'trade_id': 38769285,
#   'contract': 'OC',
#   'qty': 248,
#   'avg': 432.06,
#   'placement_time': datetime.datetime(2022, 3, 29, 11, 43, 50),
#   'filled_time': datetime.datetime(2022, 3, 29, 11, 43, 57)},
#  {'fill_id': 79920109,
#   'leg_no': 1,
#   'trade_id': 282953378,
#   'contract': 'PTC',
#   'qty': 352,
#   'avg': 207.71,
#   'placement_time': datetime.datetime(2021, 12, 31, 9, 35, 37),
#   'filled_time': datetime.datetime(2021, 12, 31, 9, 35, 39)},
#  {'fill_id': 81525401,
#   'leg_no': 1,
#   'trade_id': 675416933,
#   'contract': 'WLH',
#   'qty': 199,
#   'avg': 321.4,
#   'placement_time': datetime.datetime(2022, 3, 18, 18, 22, 9),
#   'filled_time': datetime.datetime(2022, 3, 18, 18, 22, 12)},
#  {'fill_id': 85105232,
#   'leg_no': 1,
#   'trade_id': 624536216,
#   'contract': 'MDIV',
#   'qty': -199,
#   'avg': 348.98633739,
#   'placement_time': datetime.datetime(2022, 6, 26, 9, 42, 6),
#   'filled_time': datetime.datetime(2022, 6, 26, 9, 42, 9)},
#  {'fill_id': 85525977,
#   'leg_no': 1,
#   'trade_id': 582522518,
#   'contract': 'ASV',
#   'qty': -173,
#   'avg': 266.3269703601,
#   'placement_time': datetime.datetime(2022, 1, 22, 22, 24, 4),
#   'filled_time': datetime.datetime(2022, 1, 22, 22, 24, 10)},
#  {'fill_id': 86785546,
#   'leg_no': 1,
#   'trade_id': 693880970,
#   'contract': 'IPWR',
#   'qty': 318,
#   'avg': 316.32,
#   'placement_time': datetime.datetime(2022, 5, 22, 1, 9, 41),
#   'filled_time': datetime.datetime(2022, 5, 22, 1, 9, 46)},
#  {'fill_id': 90384555,
#   'leg_no': 1,
#   'trade_id': 594965059,
#   'contract': 'NYMTP',
#   'qty': 478,
#   'avg': 352.55,
#   'placement_time': datetime.datetime(2022, 6, 9, 15, 49, 41),
#   'filled_time': datetime.datetime(2022, 6, 9, 15, 49, 48)},
#  {'fill_id': 91063616,
#   'leg_no': 1,
#   'trade_id': 171327069,
#   'contract': 'TPVZ',
#   'qty': -288,
#   'avg': 503.6193960474,
#   'placement_time': datetime.datetime(2022, 4, 21, 10, 48, 34),
#   'filled_time': datetime.datetime(2022, 4, 21, 10, 48, 35)},
#  {'fill_id': 91599283,
#   'leg_no': 1,
#   'trade_id': 657301532,
#   'contract': 'PACB',
#   'qty': 468,
#   'avg': 110.44,
#   'placement_time': datetime.datetime(2022, 4, 24, 2, 18, 14),
#   'filled_time': datetime.datetime(2022, 4, 24, 2, 18, 16)},
#  {'fill_id': 91656733,
#   'leg_no': 1,
#   'trade_id': 512536957,
#   'contract': 'ADRU',
#   'qty': 227,
#   'avg': 4.74,
#   'placement_time': datetime.datetime(2022, 7, 9, 23, 30, 26),
#   'filled_time': datetime.datetime(2022, 7, 9, 23, 30, 31)},
#  {'fill_id': 92057469,
#   'leg_no': 1,
#   'trade_id': 909594814,
#   'contract': 'MEOH',
#   'qty': 285,
#   'avg': 485.87,
#   'placement_time': datetime.datetime(2022, 5, 13, 14, 28, 1),
#   'filled_time': datetime.datetime(2022, 5, 13, 14, 28, 8)},
#  {'fill_id': 93618185,
#   'leg_no': 1,
#   'trade_id': 594752856,
#   'contract': 'AHGP',
#   'qty': -398,
#   'avg': 136.827137981,
#   'placement_time': datetime.datetime(2022, 6, 19, 0, 23, 33),
#   'filled_time': datetime.datetime(2022, 6, 19, 0, 23, 42)},
#  {'fill_id': 99321410,
#   'leg_no': 1,
#   'trade_id': 250415049,
#   'contract': 'RVLT',
#   'qty': -240,
#   'avg': 212.481097052,
#   'placement_time': datetime.datetime(2022, 6, 4, 16, 48, 54),
#   'filled_time': datetime.datetime(2022, 6, 4, 16, 49, 2)},
#  {'fill_id': 100804200,
#   'leg_no': 1,
#   'trade_id': 288431752,
#   'contract': 'ARAY',
#   'qty': 103,
#   'avg': 119.17,
#   'placement_time': datetime.datetime(2022, 8, 5, 1, 59, 28),
#   'filled_time': datetime.datetime(2022, 8, 5, 1, 59, 32)},
#  {'fill_id': 102801580,
#   'leg_no': 1,
#   'trade_id': 753593819,
#   'contract': 'CELH',
#   'qty': 113,
#   'avg': 64.93,
#   'placement_time': datetime.datetime(2022, 7, 23, 11, 55, 6),
#   'filled_time': datetime.datetime(2022, 7, 23, 11, 55, 14)},
#  {'fill_id': 107857538,
#   'leg_no': 1,
#   'trade_id': 909594814,
#   'contract': 'MEOH',
#   'qty': -285,
#   'avg': 683.8550398701,
#   'placement_time': datetime.datetime(2022, 8, 17, 15, 20, 44),
#   'filled_time': datetime.datetime(2022, 8, 17, 15, 20, 49)},
#  {'fill_id': 109310601,
#   'leg_no': 1,
#   'trade_id': 614004145,
#   'contract': 'SPE^B',
#   'qty': -293,
#   'avg': 444.7915580329,
#   'placement_time': datetime.datetime(2022, 2, 2, 23, 7, 10),
#   'filled_time': datetime.datetime(2022, 2, 2, 23, 7, 15)},
#  {'fill_id': 109331956,
#   'leg_no': 1,
#   'trade_id': 8819798,
#   'contract': 'TGI',
#   'qty': 285,
#   'avg': 482.89,
#   'placement_time': datetime.datetime(2022, 2, 26, 5, 22, 50),
#   'filled_time': datetime.datetime(2022, 2, 26, 5, 22, 52)},
#  {'fill_id': 112557235,
#   'leg_no': 1,
#   'trade_id': 965514288,
#   'contract': 'PHO',
#   'qty': 150,
#   'avg': 300.13,
#   'placement_time': datetime.datetime(2021, 12, 17, 10, 43, 52),
#   'filled_time': datetime.datetime(2021, 12, 17, 10, 43, 52)},
#  {'fill_id': 117035715,
#   'leg_no': 1,
#   'trade_id': 582522518,
#   'contract': 'ASV',
#   'qty': 173,
#   'avg': 334.17,
#   'placement_time': datetime.datetime(2022, 7, 11, 9, 11, 7),
#   'filled_time': datetime.datetime(2022, 7, 11, 9, 11, 9)},
#  {'fill_id': 118032721,
#   'leg_no': 1,
#   'trade_id': 835059712,
#   'contract': 'NGHCN',
#   'qty': 274,
#   'avg': 150.21,
#   'placement_time': datetime.datetime(2022, 6, 11, 18, 16, 58),
#   'filled_time': datetime.datetime(2022, 6, 11, 18, 17, 4)},
#  {'fill_id': 119226955,
#   'leg_no': 1,
#   'trade_id': 512536957,
#   'contract': 'ADRU',
#   'qty': -227,
#   'avg': 4.177368585,
#   'placement_time': datetime.datetime(2022, 8, 11, 4, 2, 33),
#   'filled_time': datetime.datetime(2022, 8, 11, 4, 2, 39)},
#  {'fill_id': 120119543,
#   'leg_no': 1,
#   'trade_id': 105425552,
#   'contract': 'ETX',
#   'qty': 483,
#   'avg': 378.97,
#   'placement_time': datetime.datetime(2022, 11, 7, 13, 3, 30),
#   'filled_time': datetime.datetime(2022, 11, 7, 13, 3, 40)},
#  {'fill_id': 120511505,
#   'leg_no': 1,
#   'trade_id': 708353551,
#   'contract': 'ATHM',
#   'qty': 372,
#   'avg': 340.17,
#   'placement_time': datetime.datetime(2022, 9, 26, 22, 54, 33),
#   'filled_time': datetime.datetime(2022, 9, 26, 22, 54, 41)},
#  {'fill_id': 121810008,
#   'leg_no': 1,
#   'trade_id': 30490782,
#   'contract': 'GEF.B',
#   'qty': -307,
#   'avg': 456.8246677433,
#   'placement_time': datetime.datetime(2022, 1, 29, 0, 39, 54),
#   'filled_time': datetime.datetime(2022, 1, 29, 0, 39, 58)},
#  {'fill_id': 122157457,
#   'leg_no': 1,
#   'trade_id': 668865077,
#   'contract': 'HTHT',
#   'qty': -227,
#   'avg': 108.2219415377,
#   'placement_time': datetime.datetime(2022, 5, 1, 7, 43, 23),
#   'filled_time': datetime.datetime(2022, 5, 1, 7, 43, 29)},
#  {'fill_id': 126099012,
#   'leg_no': 1,
#   'trade_id': 116185127,
#   'contract': 'JPM^G',
#   'qty': -118,
#   'avg': 356.8446906086,
#   'placement_time': datetime.datetime(2022, 10, 24, 15, 14, 40),
#   'filled_time': datetime.datetime(2022, 10, 24, 15, 14, 42)},
#  {'fill_id': 131925739,
#   'leg_no': 1,
#   'trade_id': 488906694,
#   'contract': 'GS^J',
#   'qty': 362,
#   'avg': 420.27,
#   'placement_time': datetime.datetime(2022, 4, 25, 19, 19, 36),
#   'filled_time': datetime.datetime(2022, 4, 25, 19, 19, 40)},
#  {'fill_id': 132945899,
#   'leg_no': 1,
#   'trade_id': 125875572,
#   'contract': 'SBGI',
#   'qty': -406,
#   'avg': 4.9860401482,
#   'placement_time': datetime.datetime(2022, 10, 28, 3, 44, 38),
#   'filled_time': datetime.datetime(2022, 10, 28, 3, 44, 41)},
#  {'fill_id': 133677419,
#   'leg_no': 1,
#   'trade_id': 746446204,
#   'contract': 'SNP',
#   'qty': -232,
#   'avg': 225.1991599493,
#   'placement_time': datetime.datetime(2022, 1, 25, 13, 8, 44),
#   'filled_time': datetime.datetime(2022, 1, 25, 13, 8, 51)},
#  {'fill_id': 135885569,
#   'leg_no': 1,
#   'trade_id': 660458440,
#   'contract': 'PBR.A',
#   'qty': 375,
#   'avg': 163.54,
#   'placement_time': datetime.datetime(2022, 1, 29, 14, 20, 37),
#   'filled_time': datetime.datetime(2022, 1, 29, 14, 20, 39)},
#  {'fill_id': 136603195,
#   'leg_no': 1,
#   'trade_id': 550575750,
#   'contract': 'STWD',
#   'qty': 209,
#   'avg': 406.39,
#   'placement_time': datetime.datetime(2022, 7, 21, 7, 8, 39),
#   'filled_time': datetime.datetime(2022, 7, 21, 7, 8, 46)},
#  {'fill_id': 139306703,
#   'leg_no': 1,
#   'trade_id': 366846045,
#   'contract': 'EFAS',
#   'qty': 342,
#   'avg': 217.34,
#   'placement_time': datetime.datetime(2022, 10, 13, 2, 46, 20),
#   'filled_time': datetime.datetime(2022, 10, 13, 2, 46, 26)},
#  {'fill_id': 139471026,
#   'leg_no': 1,
#   'trade_id': 511744228,
#   'contract': 'VIVE',
#   'qty': -156,
#   'avg': 276.8588903573,
#   'placement_time': datetime.datetime(2022, 8, 26, 16, 58, 7),
#   'filled_time': datetime.datetime(2022, 8, 26, 16, 58, 12)},
#  {'fill_id': 140529075,
#   'leg_no': 1,
#   'trade_id': 517518405,
#   'contract': 'BMO',
#   'qty': -276,
#   'avg': 220.1154913575,
#   'placement_time': datetime.datetime(2022, 2, 27, 2, 30, 10),
#   'filled_time': datetime.datetime(2022, 2, 27, 2, 30, 18)},
#  {'fill_id': 142356337,
#   'leg_no': 1,
#   'trade_id': 743118607,
#   'contract': 'MNST',
#   'qty': -450,
#   'avg': 328.8888519042,
#   'placement_time': datetime.datetime(2022, 8, 29, 18, 25, 51),
#   'filled_time': datetime.datetime(2022, 8, 29, 18, 25, 59)},
#  {'fill_id': 146858311,
#   'leg_no': 1,
#   'trade_id': 287455122,
#   'contract': 'SPOK',
#   'qty': -398,
#   'avg': 214.9306737975,
#   'placement_time': datetime.datetime(2022, 8, 31, 4, 36, 36),
#   'filled_time': datetime.datetime(2022, 8, 31, 4, 36, 46)},
#  {'fill_id': 148216098,
#   'leg_no': 1,
#   'trade_id': 912632634,
#   'contract': 'HVT.A',
#   'qty': -310,
#   'avg': 48.8065976175,
#   'placement_time': datetime.datetime(2022, 9, 16, 6, 37, 34),
#   'filled_time': datetime.datetime(2022, 9, 16, 6, 37, 37)},
#  {'fill_id': 148294901,
#   'leg_no': 1,
#   'trade_id': 724465022,
#   'contract': 'BSET',
#   'qty': 376,
#   'avg': 102.56,
#   'placement_time': datetime.datetime(2022, 1, 4, 10, 32, 42),
#   'filled_time': datetime.datetime(2022, 1, 4, 10, 32, 45)},
#  {'fill_id': 149624677,
#   'leg_no': 1,
#   'trade_id': 581392627,
#   'contract': 'MGYR',
#   'qty': 334,
#   'avg': 381.79,
#   'placement_time': datetime.datetime(2022, 3, 7, 4, 14, 25),
#   'filled_time': datetime.datetime(2022, 3, 7, 4, 14, 32)},
#  {'fill_id': 152274897,
#   'leg_no': 1,
#   'trade_id': 23767170,
#   'contract': 'CRBP',
#   'qty': -219,
#   'avg': 242.0549480509,
#   'placement_time': datetime.datetime(2022, 2, 12, 6, 12, 52),
#   'filled_time': datetime.datetime(2022, 2, 12, 6, 12, 57)},
#  {'fill_id': 152314317,
#   'leg_no': 1,
#   'trade_id': 847054847,
#   'contract': 'MDSO',
#   'qty': 141,
#   'avg': 187.31,
#   'placement_time': datetime.datetime(2022, 2, 17, 22, 26, 26),
#   'filled_time': datetime.datetime(2022, 2, 17, 22, 26, 31)},
#  {'fill_id': 155518072,
#   'leg_no': 1,
#   'trade_id': 250415049,
#   'contract': 'RVLT',
#   'qty': 240,
#   'avg': 236.65,
#   'placement_time': datetime.datetime(2022, 9, 16, 15, 5, 30),
#   'filled_time': datetime.datetime(2022, 9, 16, 15, 5, 34)},
#  {'fill_id': 156617214,
#   'leg_no': 1,
#   'trade_id': 169290390,
#   'contract': 'SHOO',
#   'qty': -309,
#   'avg': 459.4393395404,
#   'placement_time': datetime.datetime(2022, 7, 28, 10, 50, 55),
#   'filled_time': datetime.datetime(2022, 7, 28, 10, 50, 58)},
#  {'fill_id': 158108418,
#   'leg_no': 1,
#   'trade_id': 156658556,
#   'contract': 'PDLI',
#   'qty': -334,
#   'avg': 389.8792909943,
#   'placement_time': datetime.datetime(2022, 1, 31, 9, 10, 3),
#   'filled_time': datetime.datetime(2022, 1, 31, 9, 10, 10)},
#  {'fill_id': 159460876,
#   'leg_no': 1,
#   'trade_id': 992754499,
#   'contract': 'TRMK',
#   'qty': 326,
#   'avg': 203.46,
#   'placement_time': datetime.datetime(2021, 12, 24, 3, 45, 8),
#   'filled_time': datetime.datetime(2021, 12, 24, 3, 45, 18)},
#  {'fill_id': 160033185,
#   'leg_no': 1,
#   'trade_id': 23767170,
#   'contract': 'CRBP',
#   'qty': 219,
#   'avg': 238.04,
#   'placement_time': datetime.datetime(2022, 7, 24, 19, 21, 47),
#   'filled_time': datetime.datetime(2022, 7, 24, 19, 21, 53)},
#  {'fill_id': 160798153,
#   'leg_no': 1,
#   'trade_id': 778764675,
#   'contract': 'WABC',
#   'qty': -273,
#   'avg': 327.1828089976,
#   'placement_time': datetime.datetime(2022, 2, 7, 19, 15, 31),
#   'filled_time': datetime.datetime(2022, 2, 7, 19, 15, 34)},
#  {'fill_id': 163906167,
#   'leg_no': 1,
#   'trade_id': 592084726,
#   'contract': 'BXE',
#   'qty': -397,
#   'avg': 461.0463443985,
#   'placement_time': datetime.datetime(2022, 9, 1, 1, 6, 37),
#   'filled_time': datetime.datetime(2022, 9, 1, 1, 6, 40)},
#  {'fill_id': 164590310,
#   'leg_no': 1,
#   'trade_id': 594752856,
#   'contract': 'AHGP',
#   'qty': 398,
#   'avg': 131.05,
#   'placement_time': datetime.datetime(2022, 6, 6, 22, 54, 31),
#   'filled_time': datetime.datetime(2022, 6, 6, 22, 54, 41)},
#  {'fill_id': 165755639,
#   'leg_no': 1,
#   'trade_id': 206054292,
#   'contract': 'FTAI',
#   'qty': 168,
#   'avg': 96.63,
#   'placement_time': datetime.datetime(2022, 7, 9, 16, 50, 28),
#   'filled_time': datetime.datetime(2022, 7, 9, 16, 50, 34)},
#  {'fill_id': 166622260,
#   'leg_no': 1,
#   'trade_id': 539056113,
#   'contract': 'B',
#   'qty': -212,
#   'avg': 118.2117573769,
#   'placement_time': datetime.datetime(2022, 4, 9, 7, 29, 43),
#   'filled_time': datetime.datetime(2022, 4, 9, 7, 29, 46)},
#  {'fill_id': 167376516,
#   'leg_no': 1,
#   'trade_id': 142660041,
#   'contract': 'NI',
#   'qty': 394,
#   'avg': 162.43,
#   'placement_time': datetime.datetime(2022, 11, 14, 17, 45, 54),
#   'filled_time': datetime.datetime(2022, 11, 14, 17, 46)},
#  {'fill_id': 167807285,
#   'leg_no': 1,
#   'trade_id': 162906379,
#   'contract': 'NTZ',
#   'qty': -134,
#   'avg': 189.7036037505,
#   'placement_time': datetime.datetime(2022, 2, 18, 8, 5, 22),
#   'filled_time': datetime.datetime(2022, 2, 18, 8, 5, 27)},
#  {'fill_id': 167810540,
#   'leg_no': 1,
#   'trade_id': 318906343,
#   'contract': 'ADBE',
#   'qty': 394,
#   'avg': 349.25,
#   'placement_time': datetime.datetime(2022, 4, 3, 8, 58, 54),
#   'filled_time': datetime.datetime(2022, 4, 3, 8, 58, 57)},
#  {'fill_id': 168721234,
#   'leg_no': 1,
#   'trade_id': 594965059,
#   'contract': 'NYMTP',
#   'qty': -478,
#   'avg': 457.5951970397,
#   'placement_time': datetime.datetime(2022, 11, 19, 6, 12, 13),
#   'filled_time': datetime.datetime(2022, 11, 19, 6, 12, 14)},
#  {'fill_id': 169227022,
#   'leg_no': 1,
#   'trade_id': 826060268,
#   'contract': 'SPAN',
#   'qty': 482,
#   'avg': 286.78,
#   'placement_time': datetime.datetime(2022, 11, 27, 3, 49, 15),
#   'filled_time': datetime.datetime(2022, 11, 27, 3, 49, 15)},
#  {'fill_id': 176871936,
#   'leg_no': 1,
#   'trade_id': 851919263,
#   'contract': 'GBL',
#   'qty': 369,
#   'avg': 85.51,
#   'placement_time': datetime.datetime(2022, 9, 22, 5, 34, 29),
#   'filled_time': datetime.datetime(2022, 9, 22, 5, 34, 35)},
#  {'fill_id': 177543067,
#   'leg_no': 1,
#   'trade_id': 998104368,
#   'contract': 'XRX',
#   'qty': -235,
#   'avg': 43.7710693235,
#   'placement_time': datetime.datetime(2022, 5, 22, 6, 40, 57),
#   'filled_time': datetime.datetime(2022, 5, 22, 6, 41, 6)},
#  {'fill_id': 182220833,
#   'leg_no': 1,
#   'trade_id': 750566235,
#   'contract': 'FH',
#   'qty': -275,
#   'avg': 180.1858823175,
#   'placement_time': datetime.datetime(2022, 11, 12, 0, 38, 25),
#   'filled_time': datetime.datetime(2022, 11, 12, 0, 38, 34)},
#  {'fill_id': 182235790,
#   'leg_no': 1,
#   'trade_id': 872630201,
#   'contract': 'RDC',
#   'qty': 217,
#   'avg': 349.66,
#   'placement_time': datetime.datetime(2022, 10, 17, 23, 3, 28),
#   'filled_time': datetime.datetime(2022, 10, 17, 23, 3, 34)},
#  {'fill_id': 183585804,
#   'leg_no': 1,
#   'trade_id': 608530551,
#   'contract': 'GAB',
#   'qty': -270,
#   'avg': 398.8443480387,
#   'placement_time': datetime.datetime(2022, 2, 11, 5, 51, 52),
#   'filled_time': datetime.datetime(2022, 2, 11, 5, 52, 1)},
#  {'fill_id': 184339359,
#   'leg_no': 1,
#   'trade_id': 532339969,
#   'contract': 'PTR',
#   'qty': 109,
#   'avg': 170.55,
#   'placement_time': datetime.datetime(2021, 12, 16, 3, 5, 16),
#   'filled_time': datetime.datetime(2021, 12, 16, 3, 5, 21)},
#  {'fill_id': 184578065,
#   'leg_no': 1,
#   'trade_id': 320555851,
#   'contract': 'RTIX',
#   'qty': -460,
#   'avg': 242.7140668878,
#   'placement_time': datetime.datetime(2022, 1, 19, 5, 37, 56),
#   'filled_time': datetime.datetime(2022, 1, 19, 5, 37, 58)},
#  {'fill_id': 185606256,
#   'leg_no': 1,
#   'trade_id': 249797132,
#   'contract': 'WLB',
#   'qty': 168,
#   'avg': 384.63,
#   'placement_time': datetime.datetime(2022, 2, 3, 13, 55, 35),
#   'filled_time': datetime.datetime(2022, 2, 3, 13, 55, 44)},
#  {'fill_id': 186393315,
#   'leg_no': 1,
#   'trade_id': 731317912,
#   'contract': 'ARW',
#   'qty': 175,
#   'avg': 330.79,
#   'placement_time': datetime.datetime(2022, 1, 19, 6, 9, 54),
#   'filled_time': datetime.datetime(2022, 1, 19, 6, 9, 58)},
#  {'fill_id': 187582319,
#   'leg_no': 1,
#   'trade_id': 342919060,
#   'contract': 'PMT^A',
#   'qty': 310,
#   'avg': 345.48,
#   'placement_time': datetime.datetime(2022, 9, 7, 2, 53, 48),
#   'filled_time': datetime.datetime(2022, 9, 7, 2, 53, 50)},
#  {'fill_id': 187851663,
#   'leg_no': 1,
#   'trade_id': 286947701,
#   'contract': 'RM',
#   'qty': -197,
#   'avg': 44.3717691067,
#   'placement_time': datetime.datetime(2022, 6, 11, 22, 58, 19),
#   'filled_time': datetime.datetime(2022, 6, 11, 22, 58, 21)},
#  {'fill_id': 188155166,
#   'leg_no': 1,
#   'trade_id': 590592162,
#   'contract': 'COL',
#   'qty': -468,
#   'avg': 208.9114403953,
#   'placement_time': datetime.datetime(2022, 8, 2, 12, 22, 54),
#   'filled_time': datetime.datetime(2022, 8, 2, 12, 22, 57)},
#  {'fill_id': 191788980,
#   'leg_no': 1,
#   'trade_id': 262348555,
#   'contract': 'BICK',
#   'qty': -280,
#   'avg': 431.5215820718,
#   'placement_time': datetime.datetime(2022, 3, 27, 1, 54, 12),
#   'filled_time': datetime.datetime(2022, 3, 27, 1, 54, 22)},
#  {'fill_id': 195950954,
#   'leg_no': 1,
#   'trade_id': 994555123,
#   'contract': 'DRWI',
#   'qty': 191,
#   'avg': 337.98,
#   'placement_time': datetime.datetime(2022, 6, 7, 23, 45, 52),
#   'filled_time': datetime.datetime(2022, 6, 7, 23, 46, 1)},
#  {'fill_id': 195982840,
#   'leg_no': 1,
#   'trade_id': 592084726,
#   'contract': 'BXE',
#   'qty': 397,
#   'avg': 487.05,
#   'placement_time': datetime.datetime(2021, 12, 21, 22, 54, 19),
#   'filled_time': datetime.datetime(2021, 12, 21, 22, 54, 27)},
#  {'fill_id': 198009183,
#   'leg_no': 1,
#   'trade_id': 136795122,
#   'contract': 'LPSN',
#   'qty': -429,
#   'avg': 235.785458264,
#   'placement_time': datetime.datetime(2022, 6, 12, 0, 38, 29),
#   'filled_time': datetime.datetime(2022, 6, 12, 0, 38, 39)},
#  {'fill_id': 198439266,
#   'leg_no': 1,
#   'trade_id': 660458440,
#   'contract': 'PBR.A',
#   'qty': -375,
#   'avg': 210.2870231815,
#   'placement_time': datetime.datetime(2022, 1, 13, 15, 16, 23),
#   'filled_time': datetime.datetime(2022, 1, 13, 15, 16, 33)},
#  {'fill_id': 201073864,
#   'leg_no': 1,
#   'trade_id': 460130244,
#   'contract': 'LGF.B',
#   'qty': -265,
#   'avg': 226.8246381305,
#   'placement_time': datetime.datetime(2022, 4, 13, 3, 46, 20),
#   'filled_time': datetime.datetime(2022, 4, 13, 3, 46, 29)},
#  {'fill_id': 201371021,
#   'leg_no': 1,
#   'trade_id': 647852592,
#   'contract': 'HRS',
#   'qty': -315,
#   'avg': 77.2513372775,
#   'placement_time': datetime.datetime(2022, 12, 1, 0, 31, 8),
#   'filled_time': datetime.datetime(2022, 12, 1, 0, 31, 10)},
#  {'fill_id': 203621951,
#   'leg_no': 1,
#   'trade_id': 324101738,
#   'contract': 'QQQX',
#   'qty': -423,
#   'avg': 85.732975301,
#   'placement_time': datetime.datetime(2022, 3, 14, 4, 21, 11),
#   'filled_time': datetime.datetime(2022, 3, 14, 4, 21, 14)},
#  {'fill_id': 210114829,
#   'leg_no': 1,
#   'trade_id': 747615399,
#   'contract': 'JP',
#   'qty': 444,
#   'avg': 279.4,
#   'placement_time': datetime.datetime(2022, 2, 11, 21, 32, 16),
#   'filled_time': datetime.datetime(2022, 2, 11, 21, 32, 22)},
#  {'fill_id': 211344511,
#   'leg_no': 1,
#   'trade_id': 221275029,
#   'contract': 'TRIL',
#   'qty': 341,
#   'avg': 116.04,
#   'placement_time': datetime.datetime(2022, 6, 26, 6, 12, 23),
#   'filled_time': datetime.datetime(2022, 6, 26, 6, 12, 31)},
#  {'fill_id': 213506402,
#   'leg_no': 1,
#   'trade_id': 254513008,
#   'contract': 'FNCX',
#   'qty': -121,
#   'avg': 620.576694827,
#   'placement_time': datetime.datetime(2022, 9, 21, 5, 5, 15),
#   'filled_time': datetime.datetime(2022, 9, 21, 5, 5, 19)},
#  {'fill_id': 214013122,
#   'leg_no': 1,
#   'trade_id': 637473567,
#   'contract': 'TDC',
#   'qty': -413,
#   'avg': 12.2709345727,
#   'placement_time': datetime.datetime(2022, 8, 7, 5, 16, 49),
#   'filled_time': datetime.datetime(2022, 8, 7, 5, 16, 54)},
#  {'fill_id': 215242756,
#   'leg_no': 1,
#   'trade_id': 630469362,
#   'contract': 'KGC',
#   'qty': 123,
#   'avg': 101.31,
#   'placement_time': datetime.datetime(2022, 1, 12, 12, 44, 27),
#   'filled_time': datetime.datetime(2022, 1, 12, 12, 44, 27)},
#  {'fill_id': 216385849,
#   'leg_no': 1,
#   'trade_id': 994555123,
#   'contract': 'DRWI',
#   'qty': -191,
#   'avg': 357.873758568,
#   'placement_time': datetime.datetime(2022, 9, 9, 0, 59, 3),
#   'filled_time': datetime.datetime(2022, 9, 9, 0, 59, 4)},
#  {'fill_id': 216392122,
#   'leg_no': 1,
#   'trade_id': 712826496,
#   'contract': 'LAMR',
#   'qty': -471,
#   'avg': 277.8374333331,
#   'placement_time': datetime.datetime(2022, 8, 16, 3, 55, 2),
#   'filled_time': datetime.datetime(2022, 8, 16, 3, 55, 11)},
#  {'fill_id': 216743366,
#   'leg_no': 1,
#   'trade_id': 282075074,
#   'contract': 'ADXS',
#   'qty': -469,
#   'avg': 198.1747116266,
#   'placement_time': datetime.datetime(2022, 8, 5, 0, 48, 23),
#   'filled_time': datetime.datetime(2022, 8, 5, 0, 48, 27)},
#  {'fill_id': 217561646,
#   'leg_no': 1,
#   'trade_id': 21904830,
#   'contract': 'ANCX',
#   'qty': 251,
#   'avg': 136.23,
#   'placement_time': datetime.datetime(2022, 1, 3, 3, 10, 20),
#   'filled_time': datetime.datetime(2022, 1, 3, 3, 10, 21)},
#  {'fill_id': 221903724,
#   'leg_no': 1,
#   'trade_id': 25987240,
#   'contract': 'CPB',
#   'qty': -439,
#   'avg': 136.7215185001,
#   'placement_time': datetime.datetime(2022, 11, 12, 12, 49, 52),
#   'filled_time': datetime.datetime(2022, 11, 12, 12, 49, 55)},
#  {'fill_id': 224905557,
#   'leg_no': 1,
#   'trade_id': 452572457,
#   'contract': 'CVO',
#   'qty': -490,
#   'avg': 390.5840950084,
#   'placement_time': datetime.datetime(2022, 8, 15, 19, 4, 14),
#   'filled_time': datetime.datetime(2022, 8, 15, 19, 4, 21)},
#  {'fill_id': 228617351,
#   'leg_no': 1,
#   'trade_id': 929555760,
#   'contract': 'LBIX',
#   'qty': 183,
#   'avg': 304.51,
#   'placement_time': datetime.datetime(2022, 11, 6, 9, 29, 4),
#   'filled_time': datetime.datetime(2022, 11, 6, 9, 29, 9)},
#  {'fill_id': 228954017,
#   'leg_no': 1,
#   'trade_id': 244628470,
#   'contract': 'KMT',
#   'qty': 127,
#   'avg': 318.7,
#   'placement_time': datetime.datetime(2022, 3, 27, 14, 0, 53),
#   'filled_time': datetime.datetime(2022, 3, 27, 14, 0, 58)},
#  {'fill_id': 230495712,
#   'leg_no': 1,
#   'trade_id': 331633006,
#   'contract': 'ADHD',
#   'qty': -301,
#   'avg': 106.8160287467,
#   'placement_time': datetime.datetime(2022, 6, 12, 5, 19, 44),
#   'filled_time': datetime.datetime(2022, 6, 12, 5, 19, 52)},
#  {'fill_id': 233299323,
#   'leg_no': 1,
#   'trade_id': 262348555,
#   'contract': 'BICK',
#   'qty': 280,
#   'avg': 310.87,
#   'placement_time': datetime.datetime(2022, 8, 21, 0, 50, 51),
#   'filled_time': datetime.datetime(2022, 8, 21, 0, 50, 54)},
#  {'fill_id': 234169858,
#   'leg_no': 1,
#   'trade_id': 26853316,
#   'contract': 'VSH',
#   'qty': 489,
#   'avg': 271.57,
#   'placement_time': datetime.datetime(2022, 3, 10, 9, 19, 53),
#   'filled_time': datetime.datetime(2022, 3, 10, 9, 19, 58)},
#  {'fill_id': 237369175,
#   'leg_no': 1,
#   'trade_id': 587524774,
#   'contract': 'AIV^A',
#   'qty': -171,
#   'avg': 291.4579045945,
#   'placement_time': datetime.datetime(2022, 11, 28, 12, 13, 39),
#   'filled_time': datetime.datetime(2022, 11, 28, 12, 13, 40)},
#  {'fill_id': 241724503,
#   'leg_no': 1,
#   'trade_id': 595669051,
#   'contract': 'SUNW',
#   'qty': -386,
#   'avg': 554.6120007655,
#   'placement_time': datetime.datetime(2022, 1, 24, 15, 47, 27),
#   'filled_time': datetime.datetime(2022, 1, 24, 15, 47, 32)},
#  {'fill_id': 242847357,
#   'leg_no': 1,
#   'trade_id': 630469362,
#   'contract': 'KGC',
#   'qty': -123,
#   'avg': 105.3954102091,
#   'placement_time': datetime.datetime(2022, 2, 20, 9, 10, 3),
#   'filled_time': datetime.datetime(2022, 2, 20, 9, 10, 7)},
#  {'fill_id': 244092481,
#   'leg_no': 1,
#   'trade_id': 375500853,
#   'contract': 'CRS',
#   'qty': 144,
#   'avg': 246.85,
#   'placement_time': datetime.datetime(2022, 10, 22, 9, 17, 19),
#   'filled_time': datetime.datetime(2022, 10, 22, 9, 17, 19)},
#  {'fill_id': 245928122,
#   'leg_no': 1,
#   'trade_id': 985885601,
#   'contract': 'WBKC',
#   'qty': 452,
#   'avg': 231.98,
#   'placement_time': datetime.datetime(2022, 3, 18, 22, 11, 16),
#   'filled_time': datetime.datetime(2022, 3, 18, 22, 11, 17)},
#  {'fill_id': 248533448,
#   'leg_no': 1,
#   'trade_id': 511744228,
#   'contract': 'VIVE',
#   'qty': 156,
#   'avg': 235.48,
#   'placement_time': datetime.datetime(2022, 11, 30, 12, 24, 57),
#   'filled_time': datetime.datetime(2022, 11, 30, 12, 25)},
#  {'fill_id': 249449334,
#   'leg_no': 1,
#   'trade_id': 318906343,
#   'contract': 'ADBE',
#   'qty': -394,
#   'avg': 255.7847367819,
#   'placement_time': datetime.datetime(2022, 1, 5, 16, 37, 15),
#   'filled_time': datetime.datetime(2022, 1, 5, 16, 37, 25)},
#  {'fill_id': 253552961,
#   'leg_no': 1,
#   'trade_id': 581392627,
#   'contract': 'MGYR',
#   'qty': -334,
#   'avg': 519.9970649065,
#   'placement_time': datetime.datetime(2022, 2, 27, 22, 38, 47),
#   'filled_time': datetime.datetime(2022, 2, 27, 22, 38, 49)},
#  {'fill_id': 254590773,
#   'leg_no': 1,
#   'trade_id': 169290390,
#   'contract': 'SHOO',
#   'qty': 309,
#   'avg': 366.01,
#   'placement_time': datetime.datetime(2022, 10, 2, 15, 37, 13),
#   'filled_time': datetime.datetime(2022, 10, 2, 15, 37, 20)},
#  {'fill_id': 255524125,
#   'leg_no': 1,
#   'trade_id': 44409115,
#   'contract': 'WAGE',
#   'qty': 407,
#   'avg': 413.63,
#   'placement_time': datetime.datetime(2022, 11, 12, 16, 47, 16),
#   'filled_time': datetime.datetime(2022, 11, 12, 16, 47, 25)},
#  {'fill_id': 260149288,
#   'leg_no': 1,
#   'trade_id': 965514288,
#   'contract': 'PHO',
#   'qty': -150,
#   'avg': 443.7532531103,
#   'placement_time': datetime.datetime(2022, 3, 17, 15, 40, 18),
#   'filled_time': datetime.datetime(2022, 3, 17, 15, 40, 25)},
#  {'fill_id': 260939748,
#   'leg_no': 1,
#   'trade_id': 311914677,
#   'contract': 'CACC',
#   'qty': -111,
#   'avg': 257.1676528397,
#   'placement_time': datetime.datetime(2022, 9, 25, 15, 9, 56),
#   'filled_time': datetime.datetime(2022, 9, 25, 15, 10, 3)},
#  {'fill_id': 264626702,
#   'leg_no': 1,
#   'trade_id': 673161765,
#   'contract': 'TLND',
#   'qty': -390,
#   'avg': 84.0769202387,
#   'placement_time': datetime.datetime(2022, 8, 15, 19, 56, 40),
#   'filled_time': datetime.datetime(2022, 8, 15, 19, 56, 47)},
#  {'fill_id': 267376992,
#   'leg_no': 1,
#   'trade_id': 89251970,
#   'contract': 'TXT',
#   'qty': -374,
#   'avg': 133.349858671,
#   'placement_time': datetime.datetime(2022, 2, 2, 13, 2, 36),
#   'filled_time': datetime.datetime(2022, 2, 2, 13, 2, 44)},
#  {'fill_id': 269109954,
#   'leg_no': 1,
#   'trade_id': 848733680,
#   'contract': 'CYCC',
#   'qty': -457,
#   'avg': 294.9129507928,
#   'placement_time': datetime.datetime(2022, 10, 23, 9, 16, 22),
#   'filled_time': datetime.datetime(2022, 10, 23, 9, 16, 28)},
#  {'fill_id': 269647479,
#   'leg_no': 1,
#   'trade_id': 26853316,
#   'contract': 'VSH',
#   'qty': -489,
#   'avg': 361.0108930203,
#   'placement_time': datetime.datetime(2022, 2, 28, 11, 24, 49),
#   'filled_time': datetime.datetime(2022, 2, 28, 11, 24, 50)},
#  {'fill_id': 269859416,
#   'leg_no': 1,
#   'trade_id': 847054847,
#   'contract': 'MDSO',
#   'qty': -141,
#   'avg': 223.9287630664,
#   'placement_time': datetime.datetime(2022, 6, 23, 13, 0, 30),
#   'filled_time': datetime.datetime(2022, 6, 23, 13, 0, 36)},
#  {'fill_id': 270382517,
#   'leg_no': 1,
#   'trade_id': 517518405,
#   'contract': 'BMO',
#   'qty': 276,
#   'avg': 284.14,
#   'placement_time': datetime.datetime(2021, 12, 23, 5, 18, 6),
#   'filled_time': datetime.datetime(2021, 12, 23, 5, 18, 13)},
#  {'fill_id': 271088133,
#   'leg_no': 1,
#   'trade_id': 557782593,
#   'contract': 'ORI',
#   'qty': -356,
#   'avg': 442.9355700099,
#   'placement_time': datetime.datetime(2022, 8, 4, 5, 44, 49),
#   'filled_time': datetime.datetime(2022, 8, 4, 5, 44, 51)},
#  {'fill_id': 271124762,
#   'leg_no': 1,
#   'trade_id': 662214680,
#   'contract': 'GBLIL',
#   'qty': 119,
#   'avg': 198.09,
#   'placement_time': datetime.datetime(2022, 1, 12, 4, 38, 4),
#   'filled_time': datetime.datetime(2022, 1, 12, 4, 38, 13)},
#  {'fill_id': 273891946,
#   'leg_no': 1,
#   'trade_id': 412606721,
#   'contract': 'MFSF',
#   'qty': -372,
#   'avg': 582.2236445523,
#   'placement_time': datetime.datetime(2022, 7, 19, 14, 10, 8),
#   'filled_time': datetime.datetime(2022, 7, 19, 14, 10, 14)},
#  {'fill_id': 273925129,
#   'leg_no': 1,
#   'trade_id': 171327069,
#   'contract': 'TPVZ',
#   'qty': 288,
#   'avg': 342.04,
#   'placement_time': datetime.datetime(2022, 1, 17, 18, 45, 26),
#   'filled_time': datetime.datetime(2022, 1, 17, 18, 45, 28)},
#  {'fill_id': 275455087,
#   'leg_no': 1,
#   'trade_id': 44837238,
#   'contract': 'BTE',
#   'qty': 279,
#   'avg': 414.66,
#   'placement_time': datetime.datetime(2022, 10, 2, 6, 14, 28),
#   'filled_time': datetime.datetime(2022, 10, 2, 6, 14, 32)},
#  {'fill_id': 276277158,
#   'leg_no': 1,
#   'trade_id': 907014647,
#   'contract': 'KREF',
#   'qty': -419,
#   'avg': 324.9247111813,
#   'placement_time': datetime.datetime(2022, 7, 11, 7, 54, 7),
#   'filled_time': datetime.datetime(2022, 7, 11, 7, 54, 14)},
#  {'fill_id': 279873699,
#   'leg_no': 1,
#   'trade_id': 818775600,
#   'contract': 'LRAD',
#   'qty': -134,
#   'avg': 292.8616822517,
#   'placement_time': datetime.datetime(2022, 10, 6, 11, 53, 35),
#   'filled_time': datetime.datetime(2022, 10, 6, 11, 53, 43)},
#  {'fill_id': 281089308,
#   'leg_no': 1,
#   'trade_id': 296799067,
#   'contract': 'GS^D',
#   'qty': -480,
#   'avg': 525.6651652136,
#   'placement_time': datetime.datetime(2022, 9, 1, 1, 29, 22),
#   'filled_time': datetime.datetime(2022, 9, 1, 1, 29, 27)},
#  {'fill_id': 282712697,
#   'leg_no': 1,
#   'trade_id': 228065620,
#   'contract': 'HWBK',
#   'qty': -246,
#   'avg': 362.260412896,
#   'placement_time': datetime.datetime(2022, 9, 25, 0, 55, 54),
#   'filled_time': datetime.datetime(2022, 9, 25, 0, 55, 55)},
#  {'fill_id': 283681522,
#   'leg_no': 1,
#   'trade_id': 826060268,
#   'contract': 'SPAN',
#   'qty': -482,
#   'avg': 273.6093752487,
#   'placement_time': datetime.datetime(2022, 11, 21, 16, 58, 41),
#   'filled_time': datetime.datetime(2022, 11, 21, 16, 58, 49)},
#  {'fill_id': 284655130,
#   'leg_no': 1,
#   'trade_id': 708430465,
#   'contract': 'WAB',
#   'qty': 378,
#   'avg': 33.7,
#   'placement_time': datetime.datetime(2022, 9, 28, 5, 35, 15),
#   'filled_time': datetime.datetime(2022, 9, 28, 5, 35, 15)},
#  {'fill_id': 287693836,
#   'leg_no': 1,
#   'trade_id': 356657976,
#   'contract': 'RNR^C',
#   'qty': 317,
#   'avg': 80.3,
#   'placement_time': datetime.datetime(2022, 2, 6, 23, 46, 45),
#   'filled_time': datetime.datetime(2022, 2, 6, 23, 46, 54)},
#  {'fill_id': 289167340,
#   'leg_no': 1,
#   'trade_id': 494611732,
#   'contract': 'PCOM',
#   'qty': -279,
#   'avg': 113.0884238711,
#   'placement_time': datetime.datetime(2022, 8, 5, 5, 50, 48),
#   'filled_time': datetime.datetime(2022, 8, 5, 5, 50, 57)},
#  {'fill_id': 290742914,
#   'leg_no': 1,
#   'trade_id': 842398595,
#   'contract': 'CLR',
#   'qty': 456,
#   'avg': 464.52,
#   'placement_time': datetime.datetime(2022, 8, 27, 10, 9, 52),
#   'filled_time': datetime.datetime(2022, 8, 27, 10, 9, 55)},
#  {'fill_id': 291843161,
#   'leg_no': 1,
#   'trade_id': 704570833,
#   'contract': 'JMPB',
#   'qty': -367,
#   'avg': 432.08760905,
#   'placement_time': datetime.datetime(2022, 10, 17, 12, 48, 36),
#   'filled_time': datetime.datetime(2022, 10, 17, 12, 48, 37)},
#  {'fill_id': 297022287,
#   'leg_no': 1,
#   'trade_id': 864443046,
#   'contract': 'BLW',
#   'qty': 266,
#   'avg': 253.98,
#   'placement_time': datetime.datetime(2022, 7, 26, 14, 44, 46),
#   'filled_time': datetime.datetime(2022, 7, 26, 14, 44, 51)},
#  {'fill_id': 301406183,
#   'leg_no': 1,
#   'trade_id': 928140910,
#   'contract': 'PRE^G',
#   'qty': 423,
#   'avg': 182.52,
#   'placement_time': datetime.datetime(2022, 1, 29, 18, 16, 46),
#   'filled_time': datetime.datetime(2022, 1, 29, 18, 16, 48)},
#  {'fill_id': 302077615,
#   'leg_no': 1,
#   'trade_id': 923792033,
#   'contract': 'RLGY',
#   'qty': -289,
#   'avg': 425.2354446394,
#   'placement_time': datetime.datetime(2022, 5, 7, 7, 11, 16),
#   'filled_time': datetime.datetime(2022, 5, 7, 7, 11, 22)},
#  {'fill_id': 304551589,
#   'leg_no': 1,
#   'trade_id': 809629504,
#   'contract': 'AUPH',
#   'qty': -349,
#   'avg': 46.4525693699,
#   'placement_time': datetime.datetime(2022, 4, 25, 20, 30, 40),
#   'filled_time': datetime.datetime(2022, 4, 25, 20, 30, 41)},
#  {'fill_id': 304851221,
#   'leg_no': 1,
#   'trade_id': 26355223,
#   'contract': 'JE',
#   'qty': -423,
#   'avg': 419.3837800881,
#   'placement_time': datetime.datetime(2022, 3, 21, 22, 34, 16),
#   'filled_time': datetime.datetime(2022, 3, 21, 22, 34, 22)},
#  {'fill_id': 309849179,
#   'leg_no': 1,
#   'trade_id': 342919060,
#   'contract': 'PMT^A',
#   'qty': -310,
#   'avg': 349.595613046,
#   'placement_time': datetime.datetime(2022, 4, 30, 21, 44, 58),
#   'filled_time': datetime.datetime(2022, 4, 30, 21, 45, 3)},
#  {'fill_id': 313631909,
#   'leg_no': 1,
#   'trade_id': 923792033,
#   'contract': 'RLGY',
#   'qty': 289,
#   'avg': 475.24,
#   'placement_time': datetime.datetime(2022, 9, 18, 11, 1, 49),
#   'filled_time': datetime.datetime(2022, 9, 18, 11, 1, 54)},
#  {'fill_id': 319403978,
#   'leg_no': 1,
#   'trade_id': 88451452,
#   'contract': 'DRWI',
#   'qty': -142,
#   'avg': 58.8738792894,
#   'placement_time': datetime.datetime(2022, 7, 10, 7, 26, 17),
#   'filled_time': datetime.datetime(2022, 7, 10, 7, 26, 24)},
#  {'fill_id': 325357978,
#   'leg_no': 1,
#   'trade_id': 335095359,
#   'contract': 'SOR',
#   'qty': -254,
#   'avg': 215.6369998537,
#   'placement_time': datetime.datetime(2022, 6, 2, 0, 44, 55),
#   'filled_time': datetime.datetime(2022, 6, 2, 0, 44, 59)},
#  {'fill_id': 325899375,
#   'leg_no': 1,
#   'trade_id': 628189671,
#   'contract': 'UBFO',
#   'qty': -135,
#   'avg': 477.3284885064,
#   'placement_time': datetime.datetime(2022, 7, 15, 9, 32, 38),
#   'filled_time': datetime.datetime(2022, 7, 15, 9, 32, 43)},
#  {'fill_id': 330673734,
#   'leg_no': 1,
#   'trade_id': 571423123,
#   'contract': 'LBTYB',
#   'qty': 376,
#   'avg': 234.65,
#   'placement_time': datetime.datetime(2022, 6, 25, 8, 10, 41),
#   'filled_time': datetime.datetime(2022, 6, 25, 8, 10, 42)},
#  {'fill_id': 333021993,
#   'leg_no': 1,
#   'trade_id': 747615399,
#   'contract': 'JP',
#   'qty': -444,
#   'avg': 316.0261868056,
#   'placement_time': datetime.datetime(2022, 5, 18, 10, 12, 33),
#   'filled_time': datetime.datetime(2022, 5, 18, 10, 12, 41)},
#  {'fill_id': 336585348,
#   'leg_no': 1,
#   'trade_id': 561877915,
#   'contract': 'CTB',
#   'qty': -229,
#   'avg': 171.2289812382,
#   'placement_time': datetime.datetime(2022, 6, 18, 21, 23, 44),
#   'filled_time': datetime.datetime(2022, 6, 18, 21, 23, 47)},
#  {'fill_id': 338071648,
#   'leg_no': 1,
#   'trade_id': 480161486,
#   'contract': 'QUMU',
#   'qty': -153,
#   'avg': 315.1990573199,
#   'placement_time': datetime.datetime(2022, 9, 23, 6, 24, 48),
#   'filled_time': datetime.datetime(2022, 9, 23, 6, 24, 56)},
#  {'fill_id': 342898332,
#   'leg_no': 1,
#   'trade_id': 387343439,
#   'contract': 'AXTA',
#   'qty': 256,
#   'avg': 466.0,
#   'placement_time': datetime.datetime(2022, 6, 13, 21, 49, 32),
#   'filled_time': datetime.datetime(2022, 6, 13, 21, 49, 35)},
#  {'fill_id': 348057928,
#   'leg_no': 1,
#   'trade_id': 820638991,
#   'contract': 'VOD',
#   'qty': -491,
#   'avg': 389.2091465655,
#   'placement_time': datetime.datetime(2022, 5, 2, 17, 43, 22),
#   'filled_time': datetime.datetime(2022, 5, 2, 17, 43, 28)},
#  {'fill_id': 348964389,
#   'leg_no': 1,
#   'trade_id': 213188754,
#   'contract': 'EACQ',
#   'qty': 314,
#   'avg': 309.88,
#   'placement_time': datetime.datetime(2022, 9, 1, 19, 51, 17),
#   'filled_time': datetime.datetime(2022, 9, 1, 19, 51, 22)},
#  {'fill_id': 352455293,
#   'leg_no': 1,
#   'trade_id': 761782348,
#   'contract': 'FNFV',
#   'qty': 311,
#   'avg': 218.72,
#   'placement_time': datetime.datetime(2022, 11, 30, 4, 31, 41),
#   'filled_time': datetime.datetime(2022, 11, 30, 4, 31, 45)},
#  {'fill_id': 353804975,
#   'leg_no': 1,
#   'trade_id': 229581407,
#   'contract': 'PHD',
#   'qty': 362,
#   'avg': 122.89,
#   'placement_time': datetime.datetime(2022, 7, 21, 1, 17, 2),
#   'filled_time': datetime.datetime(2022, 7, 21, 1, 17, 4)},
#  {'fill_id': 360873608,
#   'leg_no': 1,
#   'trade_id': 915453961,
#   'contract': 'TWNKW',
#   'qty': 428,
#   'avg': 304.27,
#   'placement_time': datetime.datetime(2022, 5, 17, 9, 37, 46),
#   'filled_time': datetime.datetime(2022, 5, 17, 9, 37, 50)},
#  {'fill_id': 360953465,
#   'leg_no': 1,
#   'trade_id': 938842398,
#   'contract': 'EMD',
#   'qty': -129,
#   'avg': 74.8487468526,
#   'placement_time': datetime.datetime(2022, 1, 31, 19, 0, 15),
#   'filled_time': datetime.datetime(2022, 1, 31, 19, 0, 25)},
#  {'fill_id': 366857703,
#   'leg_no': 1,
#   'trade_id': 769321991,
#   'contract': 'JEC',
#   'qty': -448,
#   'avg': 155.3988759461,
#   'placement_time': datetime.datetime(2022, 1, 6, 16, 26, 34),
#   'filled_time': datetime.datetime(2022, 1, 6, 16, 26, 37)},
#  {'fill_id': 367608495,
#   'leg_no': 1,
#   'trade_id': 136795122,
#   'contract': 'LPSN',
#   'qty': 429,
#   'avg': 189.91,
#   'placement_time': datetime.datetime(2022, 10, 30, 21, 4, 53),
#   'filled_time': datetime.datetime(2022, 10, 30, 21, 4, 54)},
#  {'fill_id': 368358573,
#   'leg_no': 1,
#   'trade_id': 334604287,
#   'contract': 'GLMD',
#   'qty': 478,
#   'avg': 41.13,
#   'placement_time': datetime.datetime(2022, 5, 25, 14, 55, 37),
#   'filled_time': datetime.datetime(2022, 5, 25, 14, 55, 42)},
#  {'fill_id': 369519600,
#   'leg_no': 1,
#   'trade_id': 739016238,
#   'contract': 'PBCTP',
#   'qty': 355,
#   'avg': 70.92,
#   'placement_time': datetime.datetime(2022, 3, 1, 19, 46, 48),
#   'filled_time': datetime.datetime(2022, 3, 1, 19, 46, 54)},
#  {'fill_id': 369880468,
#   'leg_no': 1,
#   'trade_id': 286819083,
#   'contract': 'AMCN',
#   'qty': -246,
#   'avg': 146.9080828189,
#   'placement_time': datetime.datetime(2022, 1, 29, 19, 29, 37),
#   'filled_time': datetime.datetime(2022, 1, 29, 19, 29, 46)},
#  {'fill_id': 373126465,
#   'leg_no': 1,
#   'trade_id': 542027005,
#   'contract': 'NVMI',
#   'qty': -203,
#   'avg': 470.6997699536,
#   'placement_time': datetime.datetime(2022, 9, 20, 3, 48, 7),
#   'filled_time': datetime.datetime(2022, 9, 20, 3, 48, 16)},
#  {'fill_id': 375153720,
#   'leg_no': 1,
#   'trade_id': 139480550,
#   'contract': 'BSAC',
#   'qty': -166,
#   'avg': 192.1554617523,
#   'placement_time': datetime.datetime(2022, 5, 31, 8, 20, 37),
#   'filled_time': datetime.datetime(2022, 5, 31, 8, 20, 46)},
#  {'fill_id': 375782114,
#   'leg_no': 1,
#   'trade_id': 489476826,
#   'contract': 'UGLD',
#   'qty': -264,
#   'avg': 249.4384400685,
#   'placement_time': datetime.datetime(2022, 7, 7, 0, 53, 43),
#   'filled_time': datetime.datetime(2022, 7, 7, 0, 53, 51)},
#  {'fill_id': 377209044,
#   'leg_no': 1,
#   'trade_id': 726957289,
#   'contract': 'GAIA',
#   'qty': -220,
#   'avg': 407.4521846668,
#   'placement_time': datetime.datetime(2022, 5, 19, 16, 54, 13),
#   'filled_time': datetime.datetime(2022, 5, 19, 16, 54, 14)},
#  {'fill_id': 381759911,
#   'leg_no': 1,
#   'trade_id': 966040820,
#   'contract': 'AMZN',
#   'qty': -368,
#   'avg': 114.5925945947,
#   'placement_time': datetime.datetime(2022, 2, 18, 12, 57, 49),
#   'filled_time': datetime.datetime(2022, 2, 18, 12, 57, 58)},
#  {'fill_id': 384775296,
#   'leg_no': 1,
#   'trade_id': 23775564,
#   'contract': 'PEIX',
#   'qty': -109,
#   'avg': 241.959214966,
#   'placement_time': datetime.datetime(2022, 3, 9, 20, 31, 53),
#   'filled_time': datetime.datetime(2022, 3, 9, 20, 31, 59)},
#  {'fill_id': 384800609,
#   'leg_no': 1,
#   'trade_id': 332263631,
#   'contract': 'STWD',
#   'qty': 253,
#   'avg': 43.12,
#   'placement_time': datetime.datetime(2022, 10, 2, 0, 5, 43),
#   'filled_time': datetime.datetime(2022, 10, 2, 0, 5, 43)},
#  {'fill_id': 392231626,
#   'leg_no': 1,
#   'trade_id': 708353551,
#   'contract': 'ATHM',
#   'qty': -372,
#   'avg': 464.2007435073,
#   'placement_time': datetime.datetime(2022, 2, 17, 6, 22, 47),
#   'filled_time': datetime.datetime(2022, 2, 17, 6, 22, 52)},
#  {'fill_id': 393858172,
#   'leg_no': 1,
#   'trade_id': 139480550,
#   'contract': 'BSAC',
#   'qty': 166,
#   'avg': 238.24,
#   'placement_time': datetime.datetime(2022, 4, 21, 9, 48, 50),
#   'filled_time': datetime.datetime(2022, 4, 21, 9, 49)},
#  {'fill_id': 397335661,
#   'leg_no': 1,
#   'trade_id': 332263631,
#   'contract': 'STWD',
#   'qty': -253,
#   'avg': 46.0519221222,
#   'placement_time': datetime.datetime(2022, 3, 21, 23, 33, 44),
#   'filled_time': datetime.datetime(2022, 3, 21, 23, 33, 46)},
#  {'fill_id': 400656730,
#   'leg_no': 1,
#   'trade_id': 582022405,
#   'contract': 'NGLS^A',
#   'qty': 203,
#   'avg': 380.53,
#   'placement_time': datetime.datetime(2022, 2, 11, 0, 16, 24),
#   'filled_time': datetime.datetime(2022, 2, 11, 0, 16, 28)},
#  {'fill_id': 401030976,
#   'leg_no': 1,
#   'trade_id': 989743527,
#   'contract': 'UMPQ',
#   'qty': -466,
#   'avg': 56.9350421467,
#   'placement_time': datetime.datetime(2022, 11, 1, 19, 29, 1),
# ...
#   'filled_time': datetime.datetime(2022, 1, 14, 4, 25, 44)},
#  {'fill_id': 879072917,
#   'leg_no': 1,
#   'trade_id': 995977002,
#   'contract': 'APB',
#   'qty': 333,
#   'avg': 390.43,
#   'placement_time': datetime.datetime(2022, 7, 5, 12, 37, 59),
#   'filled_time': datetime.datetime(2022, 7, 5, 12, 37, 59)},
#  {'fill_id': 879445846,
#   'leg_no': 1,
#   'trade_id': 948705948,
#   'contract': 'VRTV',
#   'qty': 417,
#   'avg': 374.38,
#   'placement_time': datetime.datetime(2022, 5, 17, 7, 21, 1),
#   'filled_time': datetime.datetime(2022, 5, 17, 7, 21, 4)},
#  {'fill_id': 880894172,
#   'leg_no': 1,
#   'trade_id': 240899073,
#   'contract': 'FLC',
#   'qty': -433,
#   'avg': 203.0683595854,
#   'placement_time': datetime.datetime(2022, 8, 25, 9, 37, 12),
#   'filled_time': datetime.datetime(2022, 8, 25, 9, 37, 15)},
#  {'fill_id': 882583362,
#   'leg_no': 1,
#   'trade_id': 731317912,
#   'contract': 'ARW',
#   'qty': -175,
#   'avg': 446.7111149725,
#   'placement_time': datetime.datetime(2022, 2, 26, 21, 51, 12),
#   'filled_time': datetime.datetime(2022, 2, 26, 21, 51, 16)},
#  {'fill_id': 885119335,
#   'leg_no': 1,
#   'trade_id': 608530551,
#   'contract': 'GAB',
#   'qty': 270,
#   'avg': 455.2,
#   'placement_time': datetime.datetime(2022, 8, 18, 11, 32, 1),
#   'filled_time': datetime.datetime(2022, 8, 18, 11, 32, 11)},
#  {'fill_id': 887391177,
#   'leg_no': 1,
#   'trade_id': 474989301,
#   'contract': 'GFN',
#   'qty': 400,
#   'avg': 362.69,
#   'placement_time': datetime.datetime(2022, 3, 23, 7, 55, 48),
#   'filled_time': datetime.datetime(2022, 3, 23, 7, 55, 52)},
#  {'fill_id': 888206460,
#   'leg_no': 1,
#   'trade_id': 726957289,
#   'contract': 'GAIA',
#   'qty': 220,
#   'avg': 368.26,
#   'placement_time': datetime.datetime(2022, 8, 22, 5, 46, 18),
#   'filled_time': datetime.datetime(2022, 8, 22, 5, 46, 27)},
#  {'fill_id': 888695300,
#   'leg_no': 1,
#   'trade_id': 378409425,
#   'contract': 'APA',
#   'qty': -370,
#   'avg': 329.7159415913,
#   'placement_time': datetime.datetime(2022, 2, 26, 2, 11, 55),
#   'filled_time': datetime.datetime(2022, 2, 26, 2, 12, 2)},
#  {'fill_id': 889631319,
#   'leg_no': 1,
#   'trade_id': 311914677,
#   'contract': 'CACC',
#   'qty': 111,
#   'avg': 309.3,
#   'placement_time': datetime.datetime(2022, 9, 21, 16, 20, 15),
#   'filled_time': datetime.datetime(2022, 9, 21, 16, 20, 24)},
#  {'fill_id': 890346130,
#   'leg_no': 1,
#   'trade_id': 296799067,
#   'contract': 'GS^D',
#   'qty': 480,
#   'avg': 488.24,
#   'placement_time': datetime.datetime(2022, 6, 23, 7, 19, 1),
#   'filled_time': datetime.datetime(2022, 6, 23, 7, 19, 6)},
#  {'fill_id': 891473126,
#   'leg_no': 1,
#   'trade_id': 17682620,
#   'contract': 'SQM',
#   'qty': 215,
#   'avg': 195.79,
#   'placement_time': datetime.datetime(2022, 9, 12, 4, 2, 31),
#   'filled_time': datetime.datetime(2022, 9, 12, 4, 2, 38)},
#  {'fill_id': 893495947,
#   'leg_no': 1,
#   'trade_id': 493467432,
#   'contract': 'LJPC',
#   'qty': 432,
#   'avg': 495.59,
#   'placement_time': datetime.datetime(2022, 5, 19, 9, 46, 15),
#   'filled_time': datetime.datetime(2022, 5, 19, 9, 46, 24)},
#  {'fill_id': 895835870,
#   'leg_no': 1,
#   'trade_id': 488906694,
#   'contract': 'GS^J',
#   'qty': -362,
#   'avg': 431.2337561621,
#   'placement_time': datetime.datetime(2022, 4, 4, 5, 52, 10),
#   'filled_time': datetime.datetime(2022, 4, 4, 5, 52, 20)},
#  {'fill_id': 897305709,
#   'leg_no': 1,
#   'trade_id': 750566235,
#   'contract': 'FH',
#   'qty': 275,
#   'avg': 166.68,
#   'placement_time': datetime.datetime(2022, 1, 4, 10, 30, 14),
#   'filled_time': datetime.datetime(2022, 1, 4, 10, 30, 22)},
#  {'fill_id': 900964756,
#   'leg_no': 1,
#   'trade_id': 282953378,
#   'contract': 'PTC',
#   'qty': -352,
#   'avg': 167.1042083612,
#   'placement_time': datetime.datetime(2022, 2, 15, 13, 30, 14),
#   'filled_time': datetime.datetime(2022, 2, 15, 13, 30, 21)},
#  {'fill_id': 913426527,
#   'leg_no': 1,
#   'trade_id': 6304966,
#   'contract': 'TK',
#   'qty': 287,
#   'avg': 356.13,
#   'placement_time': datetime.datetime(2022, 5, 30, 15, 14, 8),
#   'filled_time': datetime.datetime(2022, 5, 30, 15, 14, 9)},
#  {'fill_id': 913756485,
#   'leg_no': 1,
#   'trade_id': 128122731,
#   'contract': 'SYNC',
#   'qty': -475,
#   'avg': 353.2924957955,
#   'placement_time': datetime.datetime(2022, 1, 4, 17, 39, 34),
#   'filled_time': datetime.datetime(2022, 1, 4, 17, 39, 35)},
#  {'fill_id': 914593303,
#   'leg_no': 1,
#   'trade_id': 887063292,
#   'contract': 'NWBI',
#   'qty': 417,
#   'avg': 431.66,
#   'placement_time': datetime.datetime(2022, 11, 30, 13, 4, 37),
#   'filled_time': datetime.datetime(2022, 11, 30, 13, 4, 40)},
#  {'fill_id': 917103057,
#   'leg_no': 1,
#   'trade_id': 114541558,
#   'contract': 'PIO',
#   'qty': 495,
#   'avg': 422.78,
#   'placement_time': datetime.datetime(2022, 7, 13, 22, 49, 31),
#   'filled_time': datetime.datetime(2022, 7, 13, 22, 49, 34)},
#  {'fill_id': 917443164,
#   'leg_no': 1,
#   'trade_id': 834471688,
#   'contract': 'YUME',
#   'qty': -357,
#   'avg': 291.7682137072,
#   'placement_time': datetime.datetime(2022, 5, 24, 22, 30, 5),
#   'filled_time': datetime.datetime(2022, 5, 24, 22, 30, 11)},
#  {'fill_id': 920868365,
#   'leg_no': 1,
#   'trade_id': 921476346,
#   'contract': 'WYNN',
#   'qty': -365,
#   'avg': 260.4319346137,
#   'placement_time': datetime.datetime(2022, 6, 24, 5, 35, 15),
#   'filled_time': datetime.datetime(2022, 6, 24, 5, 35, 17)},
#  {'fill_id': 924110946,
#   'leg_no': 1,
#   'trade_id': 474989301,
#   'contract': 'GFN',
#   'qty': -400,
#   'avg': 478.0055831286,
#   'placement_time': datetime.datetime(2022, 10, 5, 21, 2, 5),
#   'filled_time': datetime.datetime(2022, 10, 5, 21, 2, 6)},
#  {'fill_id': 927124633,
#   'leg_no': 1,
#   'trade_id': 494611732,
#   'contract': 'PCOM',
#   'qty': 279,
#   'avg': 124.91,
#   'placement_time': datetime.datetime(2022, 6, 5, 12, 29, 58),
#   'filled_time': datetime.datetime(2022, 6, 5, 12, 30, 6)},
#  {'fill_id': 927820906,
#   'leg_no': 1,
#   'trade_id': 998325118,
#   'contract': 'ATHM',
#   'qty': 237,
#   'avg': 114.37,
#   'placement_time': datetime.datetime(2022, 2, 28, 17, 7, 40),
#   'filled_time': datetime.datetime(2022, 2, 28, 17, 7, 48)},
#  {'fill_id': 928542586,
#   'leg_no': 1,
#   'trade_id': 274391853,
#   'contract': 'EQGP',
#   'qty': -337,
#   'avg': 248.9893343571,
#   'placement_time': datetime.datetime(2022, 8, 5, 0, 8, 23),
#   'filled_time': datetime.datetime(2022, 8, 5, 0, 8, 31)},
#  {'fill_id': 930783072,
#   'leg_no': 1,
#   'trade_id': 196894924,
#   'contract': 'FOMX',
#   'qty': 160,
#   'avg': 106.19,
#   'placement_time': datetime.datetime(2022, 5, 7, 7, 30),
#   'filled_time': datetime.datetime(2022, 5, 7, 7, 30, 4)},
#  {'fill_id': 932256252,
#   'leg_no': 1,
#   'trade_id': 206054292,
#   'contract': 'FTAI',
#   'qty': -168,
#   'avg': 141.8821404838,
#   'placement_time': datetime.datetime(2022, 6, 27, 4, 31, 55),
#   'filled_time': datetime.datetime(2022, 6, 27, 4, 31, 59)},
#  {'fill_id': 933864542,
#   'leg_no': 1,
#   'trade_id': 8819798,
#   'contract': 'TGI',
#   'qty': -285,
#   'avg': 600.040799279,
#   'placement_time': datetime.datetime(2022, 9, 18, 12, 18, 30),
#   'filled_time': datetime.datetime(2022, 9, 18, 12, 18, 39)},
#  {'fill_id': 934313888,
#   'leg_no': 1,
#   'trade_id': 894607348,
#   'contract': 'GSBD',
#   'qty': 242,
#   'avg': 365.93,
#   'placement_time': datetime.datetime(2021, 12, 22, 12, 22, 4),
#   'filled_time': datetime.datetime(2021, 12, 22, 12, 22, 5)},
#  {'fill_id': 935781361,
#   'leg_no': 1,
#   'trade_id': 311161537,
#   'contract': 'COLL',
#   'qty': -107,
#   'avg': 69.8187844401,
#   'placement_time': datetime.datetime(2022, 4, 13, 9, 39, 8),
#   'filled_time': datetime.datetime(2022, 4, 13, 9, 39, 10)},
#  {'fill_id': 935904254,
#   'leg_no': 1,
#   'trade_id': 695964930,
#   'contract': 'MDLZ',
#   'qty': 116,
#   'avg': 212.29,
#   'placement_time': datetime.datetime(2022, 2, 18, 11, 21, 17),
#   'filled_time': datetime.datetime(2022, 2, 18, 11, 21, 25)},
#  {'fill_id': 936685864,
#   'leg_no': 1,
#   'trade_id': 571423123,
#   'contract': 'LBTYB',
#   'qty': -376,
#   'avg': 267.6482088433,
#   'placement_time': datetime.datetime(2022, 6, 19, 21, 54, 17),
#   'filled_time': datetime.datetime(2022, 6, 19, 21, 54, 22)},
#  {'fill_id': 937573406,
#   'leg_no': 1,
#   'trade_id': 992754499,
#   'contract': 'TRMK',
#   'qty': -326,
#   'avg': 157.5331957202,
#   'placement_time': datetime.datetime(2022, 6, 16, 17, 27, 47),
#   'filled_time': datetime.datetime(2022, 6, 16, 17, 27, 52)},
#  {'fill_id': 938360160,
#   'leg_no': 1,
#   'trade_id': 221275029,
#   'contract': 'TRIL',
#   'qty': -341,
#   'avg': 140.6327068,
#   'placement_time': datetime.datetime(2022, 1, 29, 19, 1, 25),
#   'filled_time': datetime.datetime(2022, 1, 29, 19, 1, 28)},
#  {'fill_id': 938443261,
#   'leg_no': 1,
#   'trade_id': 230039270,
#   'contract': 'DSWL',
#   'qty': 277,
#   'avg': 74.6,
#   'placement_time': datetime.datetime(2022, 2, 11, 4, 42, 53),
#   'filled_time': datetime.datetime(2022, 2, 11, 4, 42, 55)},
#  {'fill_id': 944601939,
#   'leg_no': 1,
#   'trade_id': 496707528,
#   'contract': 'ENDP',
#   'qty': -204,
#   'avg': 491.8695386775,
#   'placement_time': datetime.datetime(2022, 2, 25, 8, 25, 28),
#   'filled_time': datetime.datetime(2022, 2, 25, 8, 25, 32)},
#  {'fill_id': 947223919,
#   'leg_no': 1,
#   'trade_id': 574906844,
#   'contract': 'OPP',
#   'qty': 310,
#   'avg': 199.44,
#   'placement_time': datetime.datetime(2021, 12, 8, 13, 47, 54),
#   'filled_time': datetime.datetime(2021, 12, 8, 13, 47, 58)},
#  {'fill_id': 949719739,
#   'leg_no': 1,
#   'trade_id': 119429397,
#   'contract': 'CPN',
#   'qty': 100,
#   'avg': 197.91,
#   'placement_time': datetime.datetime(2021, 12, 22, 12, 28, 3),
#   'filled_time': datetime.datetime(2021, 12, 22, 12, 28, 10)},
#  {'fill_id': 949796957,
#   'leg_no': 1,
#   'trade_id': 915453961,
#   'contract': 'TWNKW',
#   'qty': -428,
#   'avg': 450.5531988293,
#   'placement_time': datetime.datetime(2022, 5, 16, 4, 56, 58),
#   'filled_time': datetime.datetime(2022, 5, 16, 4, 57, 8)},
#  {'fill_id': 951684217,
#   'leg_no': 1,
#   'trade_id': 326142432,
#   'contract': 'FITS',
#   'qty': 269,
#   'avg': 372.05,
#   'placement_time': datetime.datetime(2022, 1, 29, 20, 20, 5),
#   'filled_time': datetime.datetime(2022, 1, 29, 20, 20, 11)},
#  {'fill_id': 953854241,
#   'leg_no': 1,
#   'trade_id': 739502250,
#   'contract': 'MON',
#   'qty': 358,
#   'avg': 93.11,
#   'placement_time': datetime.datetime(2022, 7, 14, 6, 1, 56),
#   'filled_time': datetime.datetime(2022, 7, 14, 6, 2, 1)},
#  {'fill_id': 955190154,
#   'leg_no': 1,
#   'trade_id': 755291445,
#   'contract': 'DLR^H',
#   'qty': 307,
#   'avg': 323.83,
#   'placement_time': datetime.datetime(2022, 5, 27, 13, 41, 33),
#   'filled_time': datetime.datetime(2022, 5, 27, 13, 41, 36)},
#  {'fill_id': 955408114,
#   'leg_no': 1,
#   'trade_id': 390456947,
#   'contract': 'LVHD',
#   'qty': -212,
#   'avg': 552.4775010073,
#   'placement_time': datetime.datetime(2022, 9, 23, 9, 40, 24),
#   'filled_time': datetime.datetime(2022, 9, 23, 9, 40, 34)},
#  {'fill_id': 956072868,
#   'leg_no': 1,
#   'trade_id': 560634525,
#   'contract': 'CHS',
#   'qty': 444,
#   'avg': 324.53,
#   'placement_time': datetime.datetime(2022, 2, 12, 22, 28, 54),
#   'filled_time': datetime.datetime(2022, 2, 12, 22, 29, 2)},
#  {'fill_id': 956235792,
#   'leg_no': 1,
#   'trade_id': 642506826,
#   'contract': 'ECR',
#   'qty': 357,
#   'avg': 226.81,
#   'placement_time': datetime.datetime(2022, 9, 16, 18, 15, 55),
#   'filled_time': datetime.datetime(2022, 9, 16, 18, 16, 1)},
#  {'fill_id': 959115159,
#   'leg_no': 1,
#   'trade_id': 602711048,
#   'contract': 'PTIE',
#   'qty': -267,
#   'avg': 260.8021620311,
#   'placement_time': datetime.datetime(2022, 6, 19, 19, 13, 54),
#   'filled_time': datetime.datetime(2022, 6, 19, 19, 13, 59)},
#  {'fill_id': 959401704,
#   'leg_no': 1,
#   'trade_id': 911484540,
#   'contract': 'VTIP',
#   'qty': -391,
#   'avg': 631.1283748362,
#   'placement_time': datetime.datetime(2022, 10, 3, 11, 44, 35),
#   'filled_time': datetime.datetime(2022, 10, 3, 11, 44, 40)},
#  {'fill_id': 960013745,
#   'leg_no': 1,
#   'trade_id': 459178493,
#   'contract': 'BOSC',
#   'qty': -473,
#   'avg': 260.3550384197,
#   'placement_time': datetime.datetime(2022, 2, 2, 4, 3, 21),
#   'filled_time': datetime.datetime(2022, 2, 2, 4, 3, 30)},
#  {'fill_id': 963697428,
#   'leg_no': 1,
#   'trade_id': 797589909,
#   'contract': 'JBSS',
#   'qty': 247,
#   'avg': 317.2,
#   'placement_time': datetime.datetime(2022, 2, 11, 2, 8, 33),
#   'filled_time': datetime.datetime(2022, 2, 11, 2, 8, 42)},
#  {'fill_id': 965382100,
#   'leg_no': 1,
#   'trade_id': 185231422,
#   'contract': 'XOXO',
#   'qty': -403,
#   'avg': 666.4147705251,
#   'placement_time': datetime.datetime(2022, 6, 9, 9, 3, 55),
#   'filled_time': datetime.datetime(2022, 6, 9, 9, 4, 3)},
#  {'fill_id': 966180938,
#   'leg_no': 1,
#   'trade_id': 385740146,
#   'contract': 'CYD',
#   'qty': -484,
#   'avg': 280.552675274,
#   'placement_time': datetime.datetime(2022, 1, 1, 2, 4, 44),
#   'filled_time': datetime.datetime(2022, 1, 1, 2, 4, 53)},
#  {'fill_id': 970610132,
#   'leg_no': 1,
#   'trade_id': 834471688,
#   'contract': 'YUME',
#   'qty': 357,
#   'avg': 248.64,
#   'placement_time': datetime.datetime(2022, 9, 13, 4, 20, 2),
#   'filled_time': datetime.datetime(2022, 9, 13, 4, 20, 2)},
#  {'fill_id': 972896042,
#   'leg_no': 1,
#   'trade_id': 516575097,
#   'contract': 'MRK',
#   'qty': 174,
#   'avg': 106.33,
#   'placement_time': datetime.datetime(2022, 2, 24, 21, 22, 41),
#   'filled_time': datetime.datetime(2022, 2, 24, 21, 22, 42)},
#  {'fill_id': 978433443,
#   'leg_no': 1,
#   'trade_id': 479193672,
#   'contract': 'TICC',
#   'qty': 163,
#   'avg': 134.11,
#   'placement_time': datetime.datetime(2022, 7, 4, 14, 58, 15),
#   'filled_time': datetime.datetime(2022, 7, 4, 14, 58, 17)},
#  {'fill_id': 979282486,
#   'leg_no': 1,
#   'trade_id': 21904830,
#   'contract': 'ANCX',
#   'qty': -251,
#   'avg': 179.0787786456,
#   'placement_time': datetime.datetime(2022, 7, 10, 2, 7, 25),
#   'filled_time': datetime.datetime(2022, 7, 10, 2, 7, 34)},
#  {'fill_id': 980429343,
#   'leg_no': 1,
#   'trade_id': 587524774,
#   'contract': 'AIV^A',
#   'qty': 171,
#   'avg': 249.69,
#   'placement_time': datetime.datetime(2022, 3, 5, 16, 16, 49),
#   'filled_time': datetime.datetime(2022, 3, 5, 16, 16, 58)},
#  {'fill_id': 980969611,
#   'leg_no': 1,
#   'trade_id': 274391853,
#   'contract': 'EQGP',
#   'qty': 337,
#   'avg': 355.33,
#   'placement_time': datetime.datetime(2022, 10, 19, 9, 2, 55),
#   'filled_time': datetime.datetime(2022, 10, 19, 9, 3, 1)},
#  {'fill_id': 983537263,
#   'leg_no': 1,
#   'trade_id': 76255005,
#   'contract': 'KNL',
#   'qty': -340,
#   'avg': 446.5021952629,
#   'placement_time': datetime.datetime(2022, 9, 10, 18, 16),
#   'filled_time': datetime.datetime(2022, 9, 10, 18, 16, 10)},
#  {'fill_id': 985439466,
#   'leg_no': 1,
#   'trade_id': 504316197,
#   'contract': 'FPAY',
#   'qty': -432,
#   'avg': 552.0327797345,
#   'placement_time': datetime.datetime(2022, 5, 1, 16, 39, 34),
#   'filled_time': datetime.datetime(2022, 5, 1, 16, 39, 35)},
#  {'fill_id': 987473614,
#   'leg_no': 1,
#   'trade_id': 381145924,
#   'contract': 'NEWM',
#   'qty': -291,
#   'avg': 516.7756771068,
#   'placement_time': datetime.datetime(2022, 4, 29, 16, 27, 15),
#   'filled_time': datetime.datetime(2022, 4, 29, 16, 27, 25)},
#  {'fill_id': 988682581,
#   'leg_no': 1,
#   'trade_id': 230039270,
#   'contract': 'DSWL',
#   'qty': -277,
#   'avg': 56.3827636422,
#   'placement_time': datetime.datetime(2022, 4, 12, 15, 8),
#   'filled_time': datetime.datetime(2022, 4, 12, 15, 8, 7)},
#  {'fill_id': 992439491,
#   'leg_no': 1,
#   'trade_id': 918081156,
#   'contract': 'L',
#   'qty': -291,
#   'avg': 351.0780997623,
#   'placement_time': datetime.datetime(2022, 11, 22, 16, 17, 45),
#   'filled_time': datetime.datetime(2022, 11, 22, 16, 17, 49)},
#  {'fill_id': 995212776,
#   'leg_no': 1,
#   'trade_id': 60637430,
#   'contract': 'CSL',
#   'qty': -139,
#   'avg': 313.9186988836,
#   'placement_time': datetime.datetime(2022, 2, 3, 9, 48, 40),
#   'filled_time': datetime.datetime(2022, 2, 3, 9, 48, 43)},
#  {'fill_id': 995306119,
#   'leg_no': 1,
#   'trade_id': 516575097,
#   'contract': 'MRK',
#   'qty': -174,
#   'avg': 125.0901652131,
#   'placement_time': datetime.datetime(2022, 9, 28, 12, 44, 37),
#   'filled_time': datetime.datetime(2022, 9, 28, 12, 44, 44)},
#  {'fill_id': 996156507,
#   'leg_no': 1,
#   'trade_id': 381145924,
#   'contract': 'NEWM',
#   'qty': 291,
#   'avg': 381.06,
#   'placement_time': datetime.datetime(2022, 6, 21, 7, 39, 48),
#   'filled_time': datetime.datetime(2022, 6, 21, 7, 39, 50)}]

# %%
# Testing get_strategy_info

import pandas as pd

cursor.execute('SELECT * from strategy;')
col_headers = [x[0] for x in cursor.description]
json_data = []
the_data = cursor.fetchall()
for row in the_data:
    json_data.append(dict(zip(col_headers, row)))
df = pd.DataFrame(json_data)
df
# Out:
#                      strategy_name  strategy_id  \
# 0                     BullBreakout            1
# 1                DynamicBreakoutII            2
# 2             NineEMAVWAPCrossover            3
# 3                ChinaADRArbitrage            4
# 4                          LongFTX            5
# 5          MeanReversionLunchbreak            6
# 6            ModifiedVWAPReversion            7
# 7  OrnamentalGourdFuturesArbitrage            8
# 8           BuyHighSellLowOnMargin            9
# 9          GOHMRebasePoolArbitrage           10
#
#                                   documentation_link         launch_date  \
# 0              github.com/NTS-Lightning/BullBreakout 2022-09-06 13:28:51
# 1           github.com/NTS-Lightning/DynamicBreakout 2022-07-30 01:32:10
# 2      github.com/NTS-Lightning/NineEMAVWAPCrossover 2022-10-11 22:45:34
# 3         github.com/NTS-Lightning/ChinaADRArbitrage 2022-10-02 05:00:36
# 4                   github.com/NTS-Lightning/LongFTX 2022-06-01 04:08:38
# 5             github.com/NTS-Lightning/MeanReversion 2022-09-07 05:22:14
# 6     github.com/NTS-Lightning/ModifiedVWAPReversion 2022-06-08 23:42:50
# 7  github.com/NTS-Lightning/OrnamentalGourdFuture... 2022-02-21 15:50:43
# 8    github.com/NTS-Lightning/BuyHighSellLowOnMargin 2022-10-11 14:35:16
# 9   github.com/NTS-Lightning/GOHMRebasePoolArbitrage 2022-02-13 09:19:34
#
#   termination_date
# 0              NaT
# 1              NaT
# 2              NaT
# 3              NaT
# 4              NaT
# 5              NaT
# 6              NaT
# 7       2022-12-03
# 8              NaT
# 9              NaT

# %%
# Testing get_trade_info

# TODO: FIX QUERY

cursor.execute("""
SELECT * from trade join trade_leg on trade.trade_id = trade_leg.trade_id join fill on trade_leg.leg_no = fill.leg_no and trade_leg.trade_id = fill.trade_id
where trade.trade_id = '000000002'
order by trade_leg.leg_no, fill.placement_time;
""")
col_headers = [x[0] for x in cursor.description]
json_data = []
the_data = cursor.fetchall()
for row in the_data:
    json_data.append(dict(zip(col_headers, row)))
df = pd.DataFrame(json_data)
df

# %%
# Testing get_trade_leg_info
cursor.execute("""
Select * from trade_leg join fill on trade_leg.leg_no = fill.leg_no and trade_leg.trade_id = fill.trade_id
where trade_leg.trade_id = '000000002' and trade_leg.leg_no = '1'
order by fill.placement_time;
""")
col_headers = [x[0] for x in cursor.description]
json_data = []
the_data = cursor.fetchall()
for row in the_data:
    json_data.append(dict(zip(col_headers, row)))
df = pd.DataFrame(json_data)
df

# %%
# Testing get_fill_info
cursor.execute("""
Select * from fill where fill.fill_id = '000000002';
""")
col_headers = [x[0] for x in cursor.description]
json_data = []
the_data = cursor.fetchall()
for row in the_data:
    json_data.append(dict(zip(col_headers, row)))
json_data
#df = pd.DataFrame(json_data)
#df

# %%
import pandas as pd

# Testing get_historical_trades
strategy = 'MeanReversionLunchBreak'
lookback = '2022-06-01 00:00:00'
cursor.execute(f"""
    Select trade.trade_id as trade_id, trade.open_time as open_time, trade.close_time as close_time, trade_leg.contract as contract,
    max(trade_leg.leg_no) as no_legs, count(fill.fill_id) as fills, sum(fill.qty * fill.avg) * -1 as pnl 
    from strategy 
    join trade on strategy.strategy_id = trade.strategy_id 
    join trade_leg on trade.trade_id = trade_leg.trade_id 
    join fill on trade_leg.leg_no = fill.leg_no and trade_leg.trade_id = fill.trade_id
    where strategy.strategy_name = '{strategy}'
    group by trade_id
    order by trade.open_time;
    """)
col_headers = [x[0] for x in cursor.description]
json_data = []
the_data = cursor.fetchall()
for row in the_data:
    json_data.append(dict(zip(col_headers, row)))
df = pd.DataFrame(json_data)
df.head(10)
# Out:
#     trade_id           open_time          close_time contract  no_legs  fills  \
# 0   23767170 2022-02-12 01:08:57 2022-02-12 06:12:57     CRBP        1      2
# 1  708353551 2022-02-16 22:16:52 2022-02-17 06:22:52     ATHM        1      2
# 2   26853316 2022-02-28 06:21:50 2022-02-28 11:24:50      VSH        1      2
# 3  244628470 2022-04-01 04:55:36 2022-04-01 09:19:36      KMT        1      2
# 4  230039270 2022-04-12 07:51:07 2022-04-12 15:08:07     DSWL        1      2
# 5  798894307 2022-04-26 11:50:18 2022-04-26 17:51:18     EMES        1      2
# 6  381145924 2022-04-29 13:30:25 2022-04-29 16:27:25     NEWM        1      2
# 7  300585899 2022-04-30 12:48:47 2022-04-30 15:17:47    COF^D        1      2
# 8  668865077 2022-05-01 07:17:29 2022-05-01 07:43:29     HTHT        1      2
# 9  504316197 2022-05-01 08:30:35 2022-05-01 16:39:35     FPAY        1      2
#
#             pnl
# 0    879.273623
# 1  46139.436585
# 2  43736.596687
# 3   7074.267729
# 4  -5046.174471
# 5   8952.132478
# 6  39493.262038
# 7   3897.496265
# 8     68.540729
# 9  75808.560845

# %%
# Testing get_open_trades
strategy = 'LongFTX'
cursor.execute(f"""
    Select trade.trade_id as trade_id, trade.open_time as open_time, trade_leg.contract as contract,
    max(trade_leg.leg_no) as no_legs, count(fill.fill_id) as fills, sum(fill.qty * fill.avg) as capital_out
    from strategy 
    join trade on strategy.strategy_id = trade.strategy_id 
    join trade_leg on trade.trade_id = trade_leg.trade_id 
    join fill on trade_leg.leg_no = fill.leg_no and trade_leg.trade_id = fill.trade_id
    where strategy.strategy_name = '{strategy}' and trade.close_time is NULL
    group by trade_id
    order by trade.open_time;
    """)
col_headers = [x[0] for x in cursor.description]
json_data = []
the_data = cursor.fetchall()
for row in the_data:
    json_data.append(dict(zip(col_headers, row)))
df = pd.DataFrame(json_data)
df.head(10)
# Out:
#     trade_id           open_time contract  no_legs  fills   capital_out
# 0  614004145 2022-02-02 18:12:15    SPE^B        1      2 -37715.416504
# 1  608530551 2022-02-11 02:47:01      GAB        1      2  15216.026030
# 2  517518405 2022-02-27 00:10:18      BMO        1      2  17670.764385
# 3   23775564 2022-03-09 14:34:59     PEIX        1      2  -6355.704431
# 4  376975473 2022-03-15 05:35:58     CLLS        1      2  -7275.237011
# 5  539056113 2022-04-09 05:54:46        B        1      2  -3337.252564
# 6  171327069 2022-04-21 10:28:35     TPVZ        1      2 -46534.866062
# 7  550413487 2022-04-29 18:38:24    WAFDW        1      2  -9336.061048
# 8  868094915 2022-05-10 07:31:14     AKBA        1      2 -38488.508045
# 9  942431792 2022-05-30 11:14:42    TWNKW        1      2  -2411.573140

# %%
cursor.execute('select * from strategy where termination_date is null')
col_headers = [x[0] for x in cursor.description]
json_data = []
the_data = cursor.fetchall()
for row in the_data:
    json_data.append(dict(zip(col_headers, row)))

# remove all of the documentation_link and termination_date fields from the json_data
for i in range(len(json_data)):
    del json_data[i]['documentation_link']
    del json_data[i]['termination_date']
json_data
# Out:
# [{'strategy_name': 'BullBreakout',
#   'strategy_id': 1,
#   'launch_date': datetime.datetime(2022, 9, 6, 13, 28, 51)},
#  {'strategy_name': 'DynamicBreakoutII',
#   'strategy_id': 2,
#   'launch_date': datetime.datetime(2022, 7, 30, 1, 32, 10)},
#  {'strategy_name': 'NineEMAVWAPCrossover',
#   'strategy_id': 3,
#   'launch_date': datetime.datetime(2022, 10, 11, 22, 45, 34)},
#  {'strategy_name': 'ChinaADRArbitrage',
#   'strategy_id': 4,
#   'launch_date': datetime.datetime(2022, 10, 2, 5, 0, 36)},
#  {'strategy_name': 'LongFTX',
#   'strategy_id': 5,
#   'launch_date': datetime.datetime(2022, 6, 1, 4, 8, 38)},
#  {'strategy_name': 'MeanReversionLunchbreak',
#   'strategy_id': 6,
#   'launch_date': datetime.datetime(2022, 9, 7, 5, 22, 14)},
#  {'strategy_name': 'ModifiedVWAPReversion',
#   'strategy_id': 7,
#   'launch_date': datetime.datetime(2022, 6, 8, 23, 42, 50)},
#  {'strategy_name': 'BuyHighSellLowOnMargin',
#   'strategy_id': 9,
#   'launch_date': datetime.datetime(2022, 10, 11, 14, 35, 16)},
#  {'strategy_name': 'GOHMRebasePoolArbitrage',
#   'strategy_id': 10,
#   'launch_date': datetime.datetime(2022, 2, 13, 9, 19, 34)}]

# %%
import pandas as pd
# Get the daily pnl across all trades for all data
cursor.execute("""
    Select trade.open_time as Date, sum(fill.qty * fill.avg) * -1 as pnl
    from trade
    join trade_leg on trade.trade_id = trade_leg.trade_id
    join fill on trade_leg.leg_no = fill.leg_no and trade_leg.trade_id = fill.trade_id
    group by trade.open_time
    order by trade.open_time;
    """)

col_headers = [x[0] for x in cursor.description]
json_data = []
the_data = cursor.fetchall()
for row in the_data:
    json_data.append(dict(zip(col_headers, row)))

df = pd.DataFrame(json_data)
# Group the open_time by day
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')
df = df.groupby(pd.Grouper(freq='D')).sum()
df = df.reset_index()
df['Date'] = df['Date'].dt.strftime('%Y-%m-%d')

# Convert the dataframe to a JSON object, preserving the indeces
col_headers = [x for x in df.columns]
json_data = []
for entry in df.values:
    json_data.append(dict(zip(col_headers, entry)))
json_data
# Out:
# [{'Date': '2022-01-01', 'pnl': -16415.985167384002},
#  {'Date': '2022-01-02', 'pnl': 0.0},
#  {'Date': '2022-01-03', 'pnl': -11154.757608817003},
#  {'Date': '2022-01-04', 'pnl': 2542.4355028624996},
#  {'Date': '2022-01-05', 'pnl': -54291.1398328314},
#  {'Date': '2022-01-06', 'pnl': -21504.503576147195},
#  {'Date': '2022-01-07', 'pnl': 0.0},
#  {'Date': '2022-01-08', 'pnl': 0.0},
#  {'Date': '2022-01-09', 'pnl': 0.0},
#  {'Date': '2022-01-10', 'pnl': 0.0},
#  {'Date': '2022-01-11', 'pnl': 38554.45584222958},
#  {'Date': '2022-01-12', 'pnl': 0.0},
#  {'Date': '2022-01-13', 'pnl': 28637.110495943},
#  {'Date': '2022-01-14', 'pnl': 2216.773297520802},
#  {'Date': '2022-01-15', 'pnl': 0.0},
#  {'Date': '2022-01-16', 'pnl': 0.0},
#  {'Date': '2022-01-17', 'pnl': 0.0},
#  {'Date': '2022-01-18', 'pnl': 0.0},
#  {'Date': '2022-01-19', 'pnl': -47000.929231612},
#  {'Date': '2022-01-20', 'pnl': -24412.011792547506},
#  {'Date': '2022-01-21', 'pnl': 4124.1795432117},
#  {'Date': '2022-01-22', 'pnl': -11736.844127702701},
#  {'Date': '2022-01-23', 'pnl': 0.0},
#  {'Date': '2022-01-24', 'pnl': 24539.65283768784},
#  {'Date': '2022-01-25', 'pnl': -6517.0748917624005},
#  {'Date': '2022-01-26', 'pnl': 0.0},
#  {'Date': '2022-01-27', 'pnl': 0.0},
#  {'Date': '2022-01-28', 'pnl': 3929.060293563307},
#  {'Date': '2022-01-29', 'pnl': 23447.57438944249},
#  {'Date': '2022-01-30', 'pnl': 0.0},
#  {'Date': '2022-01-31', 'pnl': 16320.851536081607},
#  {'Date': '2022-02-01', 'pnl': 0.0},
#  {'Date': '2022-02-02', 'pnl': -9385.133180888202},
#  {'Date': '2022-02-03', 'pnl': 2439.2691448203987},
#  {'Date': '2022-02-04', 'pnl': 0.0},
#  {'Date': '2022-02-05', 'pnl': 0.0},
#  {'Date': '2022-02-06', 'pnl': 0.0},
#  {'Date': '2022-02-07', 'pnl': -24746.683143655202},
#  {'Date': '2022-02-08', 'pnl': 0.0},
#  {'Date': '2022-02-09', 'pnl': 0.0},
#  {'Date': '2022-02-10', 'pnl': 0.0},
#  {'Date': '2022-02-11', 'pnl': -15216.026029551009},
#  {'Date': '2022-02-12', 'pnl': 879.2736231471063},
#  {'Date': '2022-02-13', 'pnl': 0.0},
#  {'Date': '2022-02-14', 'pnl': 0.0},
#  {'Date': '2022-02-15', 'pnl': -14293.238656857604},
#  {'Date': '2022-02-16', 'pnl': 43992.0341406011},
#  {'Date': '2022-02-17', 'pnl': 0.0},
#  {'Date': '2022-02-18', 'pnl': -46738.92461395941},
#  {'Date': '2022-02-19', 'pnl': 0.0},
#  {'Date': '2022-02-20', 'pnl': 502.5054557192998},
#  {'Date': '2022-02-21', 'pnl': 0.0},
#  {'Date': '2022-02-22', 'pnl': 0.0},
#  {'Date': '2022-02-23', 'pnl': 0.0},
#  {'Date': '2022-02-24', 'pnl': 39447.2261082253},
#  {'Date': '2022-02-25', 'pnl': 14196.324278991},
#  {'Date': '2022-02-26', 'pnl': 14671.465531451511},
#  {'Date': '2022-02-27', 'pnl': 28490.395293440997},
#  {'Date': '2022-02-28', 'pnl': 43736.59668692667},
#  {'Date': '2022-03-01', 'pnl': 0.0},
#  {'Date': '2022-03-02', 'pnl': 0.0},
#  {'Date': '2022-03-03', 'pnl': -7947.938086035996},
#  {'Date': '2022-03-04', 'pnl': 0.0},
#  {'Date': '2022-03-05', 'pnl': 0.0},
#  {'Date': '2022-03-06', 'pnl': 0.0},
#  {'Date': '2022-03-07', 'pnl': 0.0},
#  {'Date': '2022-03-08', 'pnl': 0.0},
#  {'Date': '2022-03-09', 'pnl': 6355.704431293998},
#  {'Date': '2022-03-10', 'pnl': 9650.16284835359},
#  {'Date': '2022-03-11', 'pnl': 0.0},
#  {'Date': '2022-03-12', 'pnl': -3279.3919087183986},
#  {'Date': '2022-03-13', 'pnl': 0.0},
#  {'Date': '2022-03-14', 'pnl': 19218.633637865998},
#  {'Date': '2022-03-15', 'pnl': 7773.509135443894},
#  {'Date': '2022-03-16', 'pnl': 0.0},
#  {'Date': '2022-03-17', 'pnl': 14550.80055428941},
#  {'Date': '2022-03-18', 'pnl': 0.0},
#  {'Date': '2022-03-19', 'pnl': 0.0},
#  {'Date': '2022-03-20', 'pnl': 0.0},
#  {'Date': '2022-03-21', 'pnl': -3609.294725817097},
#  {'Date': '2022-03-22', 'pnl': 0.0},
#  {'Date': '2022-03-23', 'pnl': 0.0},
#  {'Date': '2022-03-24', 'pnl': 36302.388424797595},
#  {'Date': '2022-03-25', 'pnl': 0.0},
#  {'Date': '2022-03-26', 'pnl': 33782.442980103995},
#  {'Date': '2022-03-27', 'pnl': 0.0},
#  {'Date': '2022-03-28', 'pnl': 0.0},
#  {'Date': '2022-03-29', 'pnl': 0.0},
#  {'Date': '2022-03-30', 'pnl': 28271.43070905599},
#  {'Date': '2022-03-31', 'pnl': 3191.3668735633973},
#  {'Date': '2022-04-01', 'pnl': 7074.267729096893},
#  {'Date': '2022-04-02', 'pnl': -2355.166078834809},
#  {'Date': '2022-04-03', 'pnl': 3968.8797306802007},
#  {'Date': '2022-04-04', 'pnl': 0.0},
#  {'Date': '2022-04-05', 'pnl': 0.0},
#  {'Date': '2022-04-06', 'pnl': 0.0},
#  {'Date': '2022-04-07', 'pnl': 0.0},
#  {'Date': '2022-04-08', 'pnl': 0.0},
#  {'Date': '2022-04-09', 'pnl': -6853.438696337998},
#  {'Date': '2022-04-10', 'pnl': 0.0},
#  {'Date': '2022-04-11', 'pnl': 2044.7515798668028},
#  {'Date': '2022-04-12', 'pnl': -9645.345366528103},
#  {'Date': '2022-04-13', 'pnl': -2444.0100649092983},
#  {'Date': '2022-04-14', 'pnl': 0.0},
#  {'Date': '2022-04-15', 'pnl': 0.0},
#  {'Date': '2022-04-16', 'pnl': 0.0},
#  {'Date': '2022-04-17', 'pnl': 0.0},
#  {'Date': '2022-04-18', 'pnl': 72775.26942019202},
#  {'Date': '2022-04-19', 'pnl': 0.0},
#  {'Date': '2022-04-20', 'pnl': -21413.113782317203},
#  {'Date': '2022-04-21', 'pnl': 50641.90173256249},
#  {'Date': '2022-04-22', 'pnl': 0.0},
#  {'Date': '2022-04-23', 'pnl': 0.0},
#  {'Date': '2022-04-24', 'pnl': 0.0},
#  {'Date': '2022-04-25', 'pnl': -690.8308450677014},
#  {'Date': '2022-04-26', 'pnl': 10000.120622138096},
#  {'Date': '2022-04-27', 'pnl': 0.0},
#  {'Date': '2022-04-28', 'pnl': 0.0},
#  {'Date': '2022-04-29', 'pnl': 73061.6077487813},
#  {'Date': '2022-04-30', 'pnl': 5173.336309352593},
#  {'Date': '2022-05-01', 'pnl': 39579.506469260494},
#  {'Date': '2022-05-02', 'pnl': 76060.52803775853},
#  {'Date': '2022-05-03', 'pnl': 0.0},
#  {'Date': '2022-05-04', 'pnl': 0.0},
#  {'Date': '2022-05-05', 'pnl': -1079.4458426639976},
#  {'Date': '2022-05-06', 'pnl': 0.0},
#  {'Date': '2022-05-07', 'pnl': -14451.316499213426},
#  {'Date': '2022-05-08', 'pnl': 0.0},
#  {'Date': '2022-05-09', 'pnl': 0.0},
#  {'Date': '2022-05-10', 'pnl': 41969.9706478691},
#  {'Date': '2022-05-11', 'pnl': 0.0},
#  {'Date': '2022-05-12', 'pnl': 0.0},
#  {'Date': '2022-05-13', 'pnl': -5540.11425424421},
#  {'Date': '2022-05-14', 'pnl': 0.0},
#  {'Date': '2022-05-15', 'pnl': 7415.979059073499},
#  {'Date': '2022-05-16', 'pnl': 62609.209098940395},
#  {'Date': '2022-05-17', 'pnl': 0.0},
#  {'Date': '2022-05-18', 'pnl': 4039.7840079669404},
#  {'Date': '2022-05-19', 'pnl': 51753.35106065762},
#  {'Date': '2022-05-20', 'pnl': -20021.943986054393},
#  {'Date': '2022-05-21', 'pnl': -8608.718841618604},
#  {'Date': '2022-05-22', 'pnl': 21138.047994780478},
#  {'Date': '2022-05-23', 'pnl': 0.0},
#  {'Date': '2022-05-24', 'pnl': 15396.772293470407},
#  {'Date': '2022-05-25', 'pnl': 4283.640833794199},
#  {'Date': '2022-05-26', 'pnl': -1841.916715200001},
#  {'Date': '2022-05-27', 'pnl': 101018.62128195658},
#  {'Date': '2022-05-28', 'pnl': 0.0},
#  {'Date': '2022-05-29', 'pnl': 0.0},
#  {'Date': '2022-05-30', 'pnl': 33016.484345837525},
#  {'Date': '2022-05-31', 'pnl': -7650.033349118203},
#  {'Date': '2022-06-01', 'pnl': 9547.09796283979},
#  {'Date': '2022-06-02', 'pnl': 0.0},
#  {'Date': '2022-06-03', 'pnl': 48658.694369670004},
#  {'Date': '2022-06-04', 'pnl': -5800.536707520005},
#  {'Date': '2022-06-05', 'pnl': 0.0},
#  {'Date': '2022-06-06', 'pnl': 0.0},
#  {'Date': '2022-06-07', 'pnl': 0.0},
#  {'Date': '2022-06-08', 'pnl': 0.0},
#  {'Date': '2022-06-09', 'pnl': 82967.53252161533},
#  {'Date': '2022-06-10', 'pnl': -29211.393755075005},
#  {'Date': '2022-06-11', 'pnl': 29769.894762032596},
#  {'Date': '2022-06-12', 'pnl': 0.0},
#  {'Date': '2022-06-13', 'pnl': 0.0},
#  {'Date': '2022-06-14', 'pnl': 0.0},
#  {'Date': '2022-06-15', 'pnl': 22245.059926870003},
#  {'Date': '2022-06-16', 'pnl': -14972.1381952148},
#  {'Date': '2022-06-17', 'pnl': 0.0},
#  {'Date': '2022-06-18', 'pnl': 6665.453929912597},
#  {'Date': '2022-06-19', 'pnl': 24964.91378738448},
#  {'Date': '2022-06-20', 'pnl': 0.0},
#  {'Date': '2022-06-21', 'pnl': 0.0},
#  {'Date': '2022-06-22', 'pnl': -5828.3397195953},
#  {'Date': '2022-06-23', 'pnl': 5163.2455923624},
#  {'Date': '2022-06-24', 'pnl': 35000.40491799332},
#  {'Date': '2022-06-25', 'pnl': 0.0},
#  {'Date': '2022-06-26', 'pnl': 17056.1207418884},
#  {'Date': '2022-06-27', 'pnl': -13389.5146813725},
#  {'Date': '2022-06-28', 'pnl': 0.0},
#  {'Date': '2022-06-29', 'pnl': 28144.8448238664},
#  {'Date': '2022-06-30', 'pnl': 0.0},
#  {'Date': '2022-07-01', 'pnl': 0.0},
#  {'Date': '2022-07-02', 'pnl': 0.0},
#  {'Date': '2022-07-03', 'pnl': 0.0},
#  {'Date': '2022-07-04', 'pnl': 0.0},
#  {'Date': '2022-07-05', 'pnl': 0.0},
#  {'Date': '2022-07-06', 'pnl': 9354.538502845804},
#  {'Date': '2022-07-07', 'pnl': 1700.8541514495955},
#  {'Date': '2022-07-08', 'pnl': 0.0},
#  {'Date': '2022-07-09', 'pnl': 0.0},
#  {'Date': '2022-07-10', 'pnl': 13082.974299140407},
#  {'Date': '2022-07-11', 'pnl': -22150.556015035312},
#  {'Date': '2022-07-12', 'pnl': 0.0},
#  {'Date': '2022-07-13', 'pnl': 0.0},
#  {'Date': '2022-07-14', 'pnl': 20800.38977829198},
#  {'Date': '2022-07-15', 'pnl': 21007.701969192},
#  {'Date': '2022-07-16', 'pnl': 0.0},
#  {'Date': '2022-07-17', 'pnl': 0.0},
#  {'Date': '2022-07-18', 'pnl': 0.0},
#  {'Date': '2022-07-19', 'pnl': 41743.475773455604},
#  {'Date': '2022-07-20', 'pnl': 0.0},
#  {'Date': '2022-07-21', 'pnl': 0.0},
#  {'Date': '2022-07-22', 'pnl': -4447.1005115453845},
#  {'Date': '2022-07-23', 'pnl': 0.0},
#  {'Date': '2022-07-24', 'pnl': 0.0},
#  {'Date': '2022-07-25', 'pnl': 0.0},
#  {'Date': '2022-07-26', 'pnl': -716.0113475159014},
#  {'Date': '2022-07-27', 'pnl': 0.0},
#  {'Date': '2022-07-28', 'pnl': 28869.6659179836},
#  {'Date': '2022-07-29', 'pnl': 0.0},
#  {'Date': '2022-07-30', 'pnl': 0.0},
#  {'Date': '2022-07-31', 'pnl': -6180.291121271708},
#  {'Date': '2022-08-01', 'pnl': 470.61687587999995},
#  {'Date': '2022-08-02', 'pnl': -27709.605894999608},
#  {'Date': '2022-08-03', 'pnl': 17071.480183407417},
#  {'Date': '2022-08-04', 'pnl': -35249.49430874498},
#  {'Date': '2022-08-05', 'pnl': 0.0},
#  {'Date': '2022-08-06', 'pnl': 17509.99107496979},
#  {'Date': '2022-08-07', 'pnl': -817.3540214749},
#  {'Date': '2022-08-08', 'pnl': 0.0},
#  {'Date': '2022-08-09', 'pnl': 0.0},
#  {'Date': '2022-08-10', 'pnl': 10223.030005748602},
#  {'Date': '2022-08-11', 'pnl': 0.0},
#  {'Date': '2022-08-12', 'pnl': 0.0},
#  {'Date': '2022-08-13', 'pnl': 29891.245213379196},
#  {'Date': '2022-08-14', 'pnl': 0.0},
#  {'Date': '2022-08-15', 'pnl': 25593.76208743354},
#  {'Date': '2022-08-16', 'pnl': 0.0},
#  {'Date': '2022-08-17', 'pnl': 55464.43729230847},
#  {'Date': '2022-08-18', 'pnl': 8200.026086889586},
#  {'Date': '2022-08-19', 'pnl': 0.0},
#  {'Date': '2022-08-20', 'pnl': 0.0},
#  {'Date': '2022-08-21', 'pnl': 0.0},
#  {'Date': '2022-08-22', 'pnl': -45109.94625118999},
#  {'Date': '2022-08-23', 'pnl': 0.0},
#  {'Date': '2022-08-24', 'pnl': -8635.9164802136},
#  {'Date': '2022-08-25', 'pnl': -3339.1402995218086},
#  {'Date': '2022-08-26', 'pnl': 6455.106895738805},
#  {'Date': '2022-08-27', 'pnl': 5642.436454764604},
#  {'Date': '2022-08-28', 'pnl': 0.0},
#  {'Date': '2022-08-29', 'pnl': -49338.51664310999},
#  {'Date': '2022-08-30', 'pnl': -3941.7307123749015},
#  {'Date': '2022-08-31', 'pnl': -38923.463102390524},
#  {'Date': '2022-09-01', 'pnl': 17964.07930252797},
#  {'Date': '2022-09-02', 'pnl': 0.0},
#  {'Date': '2022-09-03', 'pnl': 0.0},
#  {'Date': '2022-09-04', 'pnl': 0.0},
#  {'Date': '2022-09-05', 'pnl': 0.0},
#  {'Date': '2022-09-06', 'pnl': 0.0},
#  {'Date': '2022-09-07', 'pnl': 0.0},
#  {'Date': '2022-09-08', 'pnl': 0.0},
#  {'Date': '2022-09-09', 'pnl': 3799.7078864880095},
#  {'Date': '2022-09-10', 'pnl': 16395.546389386},
#  {'Date': '2022-09-11', 'pnl': 0.0},
#  {'Date': '2022-09-12', 'pnl': 0.0},
#  {'Date': '2022-09-13', 'pnl': 0.0},
#  {'Date': '2022-09-14', 'pnl': 1446.3693076248},
#  {'Date': '2022-09-15', 'pnl': 0.0},
#  {'Date': '2022-09-16', 'pnl': 4094.2135855769957},
#  {'Date': '2022-09-17', 'pnl': -6064.270597646995},
#  {'Date': '2022-09-18', 'pnl': 33387.977794515},
#  {'Date': '2022-09-19', 'pnl': 18081.25228744431},
#  {'Date': '2022-09-20', 'pnl': 2390.4089577996},
#  {'Date': '2022-09-21', 'pnl': 24595.27007406699},
#  {'Date': '2022-09-22', 'pnl': 0.0},
#  {'Date': '2022-09-23', 'pnl': 14362.136155534416},
#  {'Date': '2022-09-24', 'pnl': 0.0},
#  {'Date': '2022-09-25', 'pnl': -751.3941188847057},
#  {'Date': '2022-09-26', 'pnl': 0.0},
#  {'Date': '2022-09-27', 'pnl': 0.0},
#  {'Date': '2022-09-28', 'pnl': 3264.268747079401},
#  {'Date': '2022-09-29', 'pnl': -756.4524401421004},
#  {'Date': '2022-09-30', 'pnl': 0.0},
#  {'Date': '2022-10-01', 'pnl': -14.209845256111294},
#  {'Date': '2022-10-02', 'pnl': 0.0},
#  {'Date': '2022-10-03', 'pnl': 100053.44547449022},
#  {'Date': '2022-10-04', 'pnl': 18878.287077197805},
#  {'Date': '2022-10-05', 'pnl': 46126.23325143999},
#  {'Date': '2022-10-06', 'pnl': -515.6745782721991},
#  {'Date': '2022-10-07', 'pnl': 0.0},
#  {'Date': '2022-10-08', 'pnl': 6613.177954079896},
#  {'Date': '2022-10-09', 'pnl': 0.0},
#  {'Date': '2022-10-10', 'pnl': -14896.695060500395},
#  {'Date': '2022-10-11', 'pnl': 50679.407510018995},
#  {'Date': '2022-10-12', 'pnl': 0.0},
#  {'Date': '2022-10-13', 'pnl': 0.0},
#  {'Date': '2022-10-14', 'pnl': 23069.471025844796},
#  {'Date': '2022-10-15', 'pnl': 0.0},
#  {'Date': '2022-10-16', 'pnl': 0.0},
#  {'Date': '2022-10-17', 'pnl': 59867.37174913044},
#  {'Date': '2022-10-18', 'pnl': 0.0},
#  {'Date': '2022-10-19', 'pnl': 13807.328398196405},
#  {'Date': '2022-10-20', 'pnl': 0.0},
#  {'Date': '2022-10-21', 'pnl': 0.0},
#  {'Date': '2022-10-22', 'pnl': 705.7422536580052},
#  {'Date': '2022-10-23', 'pnl': -36053.38611630719},
#  {'Date': '2022-10-24', 'pnl': 127.66656625200267},
#  {'Date': '2022-10-25', 'pnl': 118341.6719532983},
#  {'Date': '2022-10-26', 'pnl': -46748.635020105576},
#  {'Date': '2022-10-27', 'pnl': -70.62769983080011},
#  {'Date': '2022-10-28', 'pnl': -1401.415935646899},
#  {'Date': '2022-10-29', 'pnl': 0.0},
#  {'Date': '2022-10-30', 'pnl': 0.0},
#  {'Date': '2022-10-31', 'pnl': 0.0},
#  {'Date': '2022-11-01', 'pnl': 8614.029640362198},
#  {'Date': '2022-11-02', 'pnl': 0.0},
#  {'Date': '2022-11-03', 'pnl': 0.0},
#  {'Date': '2022-11-04', 'pnl': -725.7969525890185},
#  {'Date': '2022-11-05', 'pnl': 45510.80715946237},
#  {'Date': '2022-11-06', 'pnl': -10769.826060088802},
#  {'Date': '2022-11-07', 'pnl': -15263.024644277102},
#  {'Date': '2022-11-08', 'pnl': 0.0},
#  {'Date': '2022-11-09', 'pnl': -18214.50770331931},
#  {'Date': '2022-11-10', 'pnl': 0.0},
#  {'Date': '2022-11-11', 'pnl': 3269.0347508342984},
#  {'Date': '2022-11-12', 'pnl': 16050.5066215439},
#  {'Date': '2022-11-13', 'pnl': -18502.15608377399},
#  {'Date': '2022-11-14', 'pnl': 0.0},
#  {'Date': '2022-11-15', 'pnl': 0.0},
#  {'Date': '2022-11-16', 'pnl': 0.0},
#  {'Date': '2022-11-17', 'pnl': 0.0},
#  {'Date': '2022-11-18', 'pnl': 0.0},
#  {'Date': '2022-11-19', 'pnl': 50211.604184976604},
#  {'Date': '2022-11-20', 'pnl': 0.0},
#  {'Date': '2022-11-21', 'pnl': -6348.241130126582},
#  {'Date': '2022-11-22', 'pnl': 11517.227030829294},
#  {'Date': '2022-11-23', 'pnl': 0.0},
#  {'Date': '2022-11-24', 'pnl': 0.0},
#  {'Date': '2022-11-25', 'pnl': 33795.88783980481},
#  {'Date': '2022-11-26', 'pnl': 0.0},
#  {'Date': '2022-11-27', 'pnl': 0.0},
#  {'Date': '2022-11-28', 'pnl': 7142.311685659501},
#  {'Date': '2022-11-29', 'pnl': -4333.862157847598},
#  {'Date': '2022-11-30', 'pnl': -9292.0787575875},
#  {'Date': '2022-12-01', 'pnl': 0.0},
#  {'Date': '2022-12-02', 'pnl': -3420.747706914999}]

# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta

lookback = 6
lookback = datetime.now() - relativedelta(months=lookback)
lookback = lookback.strftime("%Y-%m-%d %H:%M:%S")
lookback
# Out:
# '2022-06-13 01:07:03'

# %%
# Fixing daily pnl
strategy = 'LongFTX'
cursor.execute(f"""
                Select trade.open_time as Date, sum(fill.qty * fill.avg) * -1 as PNL
                from trade
                join trade_leg on trade.trade_id = trade_leg.trade_id
                join fill on trade_leg.leg_no = fill.leg_no and trade_leg.trade_id = fill.trade_id
                join strategy on trade.strategy_id = strategy.strategy_id
                where strategy.strategy_name = "{strategy}"
                group by trade.open_time
                order by trade.open_time;
                """)
# Convert this output to a dataframe
col_headers = [x[0] for x in cursor.description]
json_data = []
the_data = cursor.fetchall()
for row in the_data:
    json_data.append(dict(zip(col_headers, row)))
df = pd.DataFrame(json_data)
# Out:
#                   Date           PNL
# 0  2022-02-02 18:12:15  37715.416504
# 1  2022-02-11 02:47:01 -15216.026030
# 2  2022-02-27 00:10:18 -17670.764385
# 3  2022-03-09 14:34:59   6355.704431
# 4  2022-03-15 05:35:58   7275.237011
# 5  2022-04-09 05:54:46   3337.252564
# 6  2022-04-21 10:28:35  46534.866062
# 7  2022-04-29 18:38:24   9336.061048
# 8  2022-05-10 07:31:14  38488.508045
# 9  2022-05-30 11:14:42   2411.573140
# 10 2022-08-10 20:29:39   -127.717331
# 11 2022-08-24 21:58:40 -15103.489381
# 12 2022-08-29 17:00:59 -49338.516643
# 13 2022-09-09 00:58:04   3799.707886
# 14 2022-09-23 05:25:56   6052.535770
# 15 2022-09-28 11:38:44   3264.268747
# 16 2022-10-08 01:26:05   5486.062420
# 17 2022-10-17 10:00:28   9222.249228
# 18 2022-10-28 20:33:47  -1401.415936
# 19 2022-11-04 14:05:37   2195.795819
# 20 2022-11-05 05:00:57   7950.027613
# 21 2022-11-05 06:51:26  29518.935901
# 22 2022-11-09 20:37:02 -18214.507703
# 23 2022-11-28 04:55:40   7142.311686
